# %%
import elevation_pull as ep 
import json
from pprint import pprint
import math

# %%
with open('../data/analysed_dis_data.json', 'r') as f:
    map_data = json.load(f)

# %%
# with open('../data/analysed_dis_data.json', 'r') as f:
#     map_data = json.load(f)

# coords_list = []
# dist_list = []

# for keys, values in map_data.items():
#     for keys, values in values.items():
#         if "section" in keys:
#             if not values['climb']:
#                 coords_list.append(values['coords'])
#                 dist_list.append(values['distance'])
#             else:
#                 pass


# print(len(coords_list), len(dist_list))


# test_coords = coords_list[0]
# test_dist = dist_list[0]
# tp1 = [test_coords[0], test_coords[1]]
# tp2 = [test_coords[2], test_coords[3]]
# climb_test = ep.find_climb(tp1,tp2)
# angle_test = ep.find_incline_angle(test_dist, climb_test)

# print(climb_test, angle_test)

# %%
# Load the data
print("Loading data from '../data/analysed_dis_data.json'...")
with open('../data/analysed_dis_data.json', 'r') as f:
    map_data = json.load(f)

# Initialize counters for debugging
total_sections = 0
missing_data_sections = 0
processed_sections = 0

# Process each section
for outer_key, outer_value in map_data.items():
    print(f"\nProcessing group: {outer_key}")
    group_sections = 0
    group_fixed = 0
    
    for section_key, section_value in outer_value.items():
        if "section" in section_key:
            total_sections += 1
            group_sections += 1
            
            # Check if climb or avg_incline_angle is missing
            if not section_value['climb'] or not section_value['avg_incline_angle']:
                missing_data_sections += 1
                group_fixed += 1
                
                # Extract coordinates and distance
                coords = section_value['coords']
                distance = section_value['distance']
                
                print(f"  Fixing {section_key}:")
                print(f"    - Original data: climb={section_value['climb']}, angle={section_value['avg_incline_angle']}")
                print(f"    - Coords: {coords}")
                print(f"    - Distance: {distance}")
                
                try:
                    # Define points
                    point1 = [coords[0], coords[1]]
                    point2 = [coords[2], coords[3]]
                    
                    # Calculate missing values
                    climb = ep.find_climb(point1, point2)
                    angle = ep.find_incline_angle(distance, climb)
                    
                    # Update the data
                    section_value['climb'] = climb
                    section_value['avg_incline_angle'] = angle
                    
                    print(f"    - New values: climb={climb}, angle={angle}")
                    processed_sections += 1
                except Exception as e:
                    print(f"    - ERROR: {e}")
    
    print(f"  Group summary: {group_sections} sections, {group_fixed} sections fixed")

# Save the updated data to a new file
output_path = '../data/fixed_analysed_dis_data.json'
print(f"\nSaving updated data to '{output_path}'...")
with open(output_path, 'w') as f:
    json.dump(map_data, f, indent=2)

# Final summary
print("\nProcessing complete!")
print(f"Total sections: {total_sections}")
print(f"Sections with missing data: {missing_data_sections}")
print(f"Sections successfully processed: {processed_sections}")
print(f"Success rate: {(processed_sections / missing_data_sections * 100) if missing_data_sections > 0 else 0:.2f}%")
# Out:
# Loading data from '../data/analysed_dis_data.json'...
#
# Processing group: path1
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path2
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path3
#   Group summary: 11 sections, 0 sections fixed
#
# Processing group: path4
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path5
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path6
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path7
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path8
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path9
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path10
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path11
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path12
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path13
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path14
#   Group summary: 11 sections, 0 sections fixed
#
# Processing group: path15
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path16
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path17
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path18
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path19
#   Fixing section1_1:
#     - Original data: climb=0.0009307861328053946, angle=0.0
#     - Coords: [-2.6128154500000003, 51.452631025, -2.6127229, 51.452478049999996]
#     - Distance: 19.852546350111723
#     - New values: climb=0.0009307861328053946, angle=0.0
#   Group summary: 8 sections, 1 sections fixed
#
# Processing group: path20
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path21
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path22
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path23
#   Group summary: 10 sections, 0 sections fixed
#
# Processing group: path24
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path25
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path26
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path27
#   Group summary: 10 sections, 0 sections fixed
#
# Processing group: path28
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path29
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path30
#   Group summary: 12 sections, 0 sections fixed
#
# Processing group: path31
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path32
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path33
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path34
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path35
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path36
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path37
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path38
#   Group summary: 13 sections, 0 sections fixed
#
# Processing group: path39
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path40
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path41
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path42
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path43
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path44
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path45
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path46
#   Group summary: 18 sections, 0 sections fixed
#
# Processing group: path47
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path48
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path49
#   Group summary: 11 sections, 0 sections fixed
#
# Processing group: path50
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path51
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path52
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path53
#   Group summary: 13 sections, 0 sections fixed
#
# Processing group: path54
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path55
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path56
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path57
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path58
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path59
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path60
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path61
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path62
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path63
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path64
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path65
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path66
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path67
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path68
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path69
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path70
#   Group summary: 16 sections, 0 sections fixed
#
# Processing group: path71
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path72
#   Fixing section2_1:
#     - Original data: climb=0.00028228759765625, angle=0.0
#     - Coords: [-2.61130585, 51.457414799999995, -2.6111968, 51.4574036]
#     - Distance: 12.122528021164868
#     - New values: climb=0.00028228759765625, angle=0.0
#   Group summary: 5 sections, 1 sections fixed
#
# Processing group: path73
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path74
#   Group summary: 15 sections, 0 sections fixed
#
# Processing group: path75
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path76
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path77
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path78
#   Group summary: 15 sections, 0 sections fixed
#
# Processing group: path79
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path80
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path81
#   Group summary: 18 sections, 0 sections fixed
#
# Processing group: path82
#   Group summary: 11 sections, 0 sections fixed
#
# Processing group: path83
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path84
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path85
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path86
#   Group summary: 9 sections, 0 sections fixed
#
# Processing group: path87
#   Group summary: 10 sections, 0 sections fixed
#
# Processing group: path88
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path89
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path90
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path91
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path92
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path93
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path94
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path95
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path96
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path97
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path98
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path99
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path100
#   Group summary: 20 sections, 0 sections fixed
#
# Processing group: path101
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path102
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path103
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path104
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path105
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path106
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path107
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path108
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path109
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path110
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path111
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path112
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path113
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path114
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path115
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path116
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path117
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path118
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path119
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path120
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path121
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path122
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path123
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path124
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path125
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path126
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path127
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path128
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path129
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path130
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path131
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path132
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path133
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path134
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path135
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path136
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path137
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path138
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path139
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path140
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path141
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path142
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path143
#   Group summary: 6 sections, 0 sections fixed
#
# Processing group: path144
#   Group summary: 14 sections, 0 sections fixed
#
# Processing group: path145
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path146
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path147
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path148
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path149
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path150
#   Group summary: 12 sections, 0 sections fixed
#
# Processing group: path151
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path152
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path153
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path154
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path155
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path156
#   Group summary: 7 sections, 0 sections fixed
#
# Processing group: path157
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path158
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path159
#   Group summary: 8 sections, 0 sections fixed
#
# Processing group: path160
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path161
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path162
#   Group summary: 4 sections, 0 sections fixed
#
# Processing group: path163
#   Group summary: 3 sections, 0 sections fixed
#
# Processing group: path164
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path165
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6028318666666665, 51.459787, -2.6029079, 51.4599008]
#     - Distance: 15.193407370849037
#     - New values: climb=-0.49129486083984375, angle=-1.85
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6029079, 51.4599008, -2.6027469666666665, 51.45994205]
#     - Distance: 18.37718303863247
#     - New values: climb=0.6068878173828125, angle=1.89
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6027469666666665, 51.45994205, -2.6025860333333335, 51.4599833]
#     - Distance: 18.37718303863247
#     - New values: climb=0.49506378173828125, angle=1.54
#   Fixing section2_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6025860333333335, 51.4599833, -2.6024251, 51.46002455]
#     - Distance: 18.37718303863247
#     - New values: climb=-0.03177642822265625, angle=-0.1
#   Fixing section2_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6024251, 51.46002455, -2.6022641666666666, 51.4600658]
#     - Distance: 18.37718303863247
#     - New values: climb=0.01775360107421875, angle=0.06
#   Fixing section2_4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6022641666666666, 51.4600658, -2.6021032333333336, 51.46010705]
#     - Distance: 18.37718303863247
#     - New values: climb=0.058349609375, angle=0.18
#   Fixing section2_5:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6021032333333336, 51.46010705, -2.6019423, 51.4601483]
#     - Distance: 18.37718303863247
#     - New values: climb=-0.35472869873046875, angle=-1.11
#   Group summary: 10 sections, 7 sections fixed
#
# Processing group: path166
#   Fixing section5:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6026611, 51.4580626, -2.60276115, 51.458130499999996]
#     - Distance: 13.394378518662554
#     - New values: climb=-0.257598876953125, angle=-1.1
#   Fixing section5_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60276115, 51.458130499999996, -2.6028612, 51.4581984]
#     - Distance: 13.394378518662554
#     - New values: climb=-0.38579559326171875, angle=-1.65
#   Group summary: 27 sections, 2 sections fixed
#
# Processing group: path167
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.612128, 51.4518918, -2.6119591857142854, 51.451949]
#     - Distance: 19.720915899470736
#     - New values: climb=-1.1171836853027344, angle=-3.24
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6119591857142854, 51.451949, -2.6117903714285715, 51.4520062]
#     - Distance: 19.720915899470736
#     - New values: climb=-1.319690704345696, angle=-3.83
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6117903714285715, 51.4520062, -2.611621557142857, 51.4520634]
#     - Distance: 19.720915899470736
#     - New values: climb=-1.596965789794936, angle=-4.63
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611621557142857, 51.4520634, -2.611452742857143, 51.4521206]
#     - Distance: 19.720915899470736
#     - New values: climb=-1.0571022033691335, angle=-3.07
#   Fixing section1_4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611452742857143, 51.4521206, -2.6112839285714284, 51.4521778]
#     - Distance: 19.720915899470736
#     - New values: climb=-1.1333465576171804, angle=-3.29
#   Fixing section1_5:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6112839285714284, 51.4521778, -2.6111151142857145, 51.452235]
#     - Distance: 19.720915899470736
#     - New values: climb=-1.1826019287109446, angle=-3.43
#   Fixing section1_6:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6111151142857145, 51.452235, -2.6109463, 51.4522922]
#     - Distance: 19.720915899470736
#     - New values: climb=-1.0557022094726562, angle=-3.06
#   Group summary: 7 sections, 7 sections fixed
#
# Processing group: path168
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.612128, 51.4518918, -2.6120231499999997, 51.45180465]
#     - Distance: 15.111075264256993
#     - New values: climb=-0.5306243896484304, angle=-2.01
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6120231499999997, 51.45180465, -2.6119183, 51.4517175]
#     - Distance: 15.111075264256993
#     - New values: climb=-1.1974563598632955, angle=-4.53
#   Group summary: 2 sections, 2 sections fixed
#
# Processing group: path169
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.612128, 51.4518918, -2.6122441, 51.451986649999995]
#     - Distance: 16.615290270923715
#     - New values: climb=0.6041526794433594, angle=2.08
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6122441, 51.451986649999995, -2.6123602, 51.4520815]
#     - Distance: 16.615290270923715
#     - New values: climb=0.3481101989746094, angle=1.2
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6123602, 51.4520815, -2.612449, 51.4521268]
#     - Distance: 11.036021931602178
#     - New values: climb=0.9937820434570312, angle=5.15
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.612449, 51.4521268, -2.6125378, 51.4521721]
#     - Distance: 11.036021931602178
#     - New values: climb=1.1236724853515696, angle=5.81
#   Fixing section3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6125378, 51.4521721, -2.61263035, 51.452325075]
#     - Distance: 19.852546350111723
#     - New values: climb=0.6850547790527273, angle=1.98
#   Fixing section3_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61263035, 51.452325075, -2.6127229, 51.452478049999996]
#     - Distance: 19.852546350111723
#     - New values: climb=0.20207977294921875, angle=0.58
#   Fixing section3_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6127229, 51.452478049999996, -2.6128154500000003, 51.452631025]
#     - Distance: 19.852546350111723
#     - New values: climb=-0.0009307861328053946, angle=-0.0
#   Fixing section3_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6128154500000003, 51.452631025, -2.612908, 51.452784]
#     - Distance: 19.852546350111723
#     - New values: climb=0.8165588378906179, angle=2.36
#   Group summary: 8 sections, 8 sections fixed
#
# Processing group: path170
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6109463, 51.4522922, -2.6111151142857145, 51.452235]
#     - Distance: 19.720915899470736
#     - New values: climb=1.0557022094726562, angle=3.06
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6111151142857145, 51.452235, -2.6112839285714284, 51.4521778]
#     - Distance: 19.720915899470736
#     - New values: climb=1.1826019287109446, angle=3.43
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6112839285714284, 51.4521778, -2.611452742857143, 51.4521206]
#     - Distance: 19.720915899470736
#     - New values: climb=1.1333465576171804, angle=3.29
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611452742857143, 51.4521206, -2.611621557142857, 51.4520634]
#     - Distance: 19.720915899470736
#     - New values: climb=1.0571022033691335, angle=3.07
#   Fixing section1_4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611621557142857, 51.4520634, -2.6117903714285715, 51.4520062]
#     - Distance: 19.720915899470736
#     - New values: climb=1.596965789794936, angle=4.63
#   Fixing section1_5:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6117903714285715, 51.4520062, -2.6119591857142854, 51.451949]
#     - Distance: 19.720915899470736
#     - New values: climb=1.319690704345696, angle=3.83
#   Fixing section1_6:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6119591857142854, 51.451949, -2.612128, 51.4518918]
#     - Distance: 19.720915899470736
#     - New values: climb=1.1171836853027344, angle=3.24
#   Group summary: 7 sections, 7 sections fixed
#
# Processing group: path171
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path172
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6119183, 51.4517175, -2.6120231499999997, 51.45180465]
#     - Distance: 15.111075264256993
#     - New values: climb=1.1974563598632955, angle=4.53
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6120231499999997, 51.45180465, -2.612128, 51.4518918]
#     - Distance: 15.111075264256993
#     - New values: climb=0.5306243896484304, angle=2.01
#   Group summary: 2 sections, 2 sections fixed
#
# Processing group: path173
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path174
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6112864, 51.4587675, -2.611166566666667, 51.4588331]
#     - Distance: 15.126138680391485
#     - New values: climb=-0.43890380859375, angle=-1.66
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611166566666667, 51.4588331, -2.611046733333333, 51.4588987]
#     - Distance: 15.126138680391485
#     - New values: climb=-0.07558441162108664, angle=-0.29
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611046733333333, 51.4588987, -2.6109269, 51.4589643]
#     - Distance: 15.126138680391485
#     - New values: climb=-0.4003448486328125, angle=-1.52
#   Group summary: 3 sections, 3 sections fixed
#
# Processing group: path175
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6112864, 51.4587675, -2.6114135666666667, 51.4586954]
#     - Distance: 16.186913077048917
#     - New values: climb=0.4359436035156321, angle=1.54
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6114135666666667, 51.4586954, -2.6115407333333334, 51.4586233]
#     - Distance: 16.186913077048917
#     - New values: climb=0.7454414367675781, angle=2.64
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6115407333333334, 51.4586233, -2.6116679, 51.4585512]
#     - Distance: 16.186913077048917
#     - New values: climb=0.6632881164550852, angle=2.35
#   Fixing section3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6117841, 51.4584858, -2.611931766666667, 51.458387466666665]
#     - Distance: 19.651868818956967
#     - New values: climb=0.6965141296386648, angle=2.03
#   Fixing section3_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611931766666667, 51.458387466666665, -2.6120794333333333, 51.45828913333333]
#     - Distance: 19.651868818956967
#     - New values: climb=0.5653457641601491, angle=1.65
#   Fixing section3_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6120794333333333, 51.45828913333333, -2.6122271, 51.4581908]
#     - Distance: 19.651868818956967
#     - New values: climb=0.1633453369140767, angle=0.48
#   Group summary: 8 sections, 6 sections fixed
#
# Processing group: path176
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6109269, 51.4589643, -2.6107793, 51.459025425]
#     - Distance: 17.68001481339341
#     - New values: climb=-0.47454071044921875, angle=-1.54
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6107793, 51.459025425, -2.6106317, 51.459086549999995]
#     - Distance: 17.68001481339341
#     - New values: climb=0.21498489379882812, angle=0.7
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6106317, 51.459086549999995, -2.6104841, 51.459147675]
#     - Distance: 17.68001481339341
#     - New values: climb=0.12051010131835938, angle=0.39
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6104841, 51.459147675, -2.6103365, 51.4592088]
#     - Distance: 17.68001481339341
#     - New values: climb=-0.23052978515625, angle=-0.75
#   Fixing section1_4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6103365, 51.4592088, -2.6101889000000003, 51.459269925]
#     - Distance: 17.68001481339341
#     - New values: climb=-0.5210342407226562, angle=-1.69
#   Fixing section1_5:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6101889000000003, 51.459269925, -2.6100413000000002, 51.45933105]
#     - Distance: 17.68001481339341
#     - New values: climb=-0.333568572998054, angle=-1.08
#   Fixing section1_6:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6100413000000002, 51.45933105, -2.6098937, 51.459392175]
#     - Distance: 17.68001481339341
#     - New values: climb=-0.18312454223631391, angle=-0.59
#   Fixing section1_7:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6098937, 51.459392175, -2.6097461, 51.4594533]
#     - Distance: 17.68001481339341
#     - New values: climb=-0.0941009521484446, angle=-0.3
#   Group summary: 8 sections, 8 sections fixed
#
# Processing group: path177
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6109269, 51.4589643, -2.611046733333333, 51.4588987]
#     - Distance: 15.126138680391485
#     - New values: climb=0.4003448486328125, angle=1.52
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611046733333333, 51.4588987, -2.611166566666667, 51.4588331]
#     - Distance: 15.126138680391485
#     - New values: climb=0.07558441162108664, angle=0.29
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611166566666667, 51.4588331, -2.6112864, 51.4587675]
#     - Distance: 15.126138680391485
#     - New values: climb=0.43890380859375, angle=1.66
#   Group summary: 3 sections, 3 sections fixed
#
# Processing group: path178
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6109269, 51.4589643, -2.61104585, 51.459065124999995]
#     - Distance: 17.283440724227724
#     - New values: climb=0.7593955993652344, angle=2.52
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61104585, 51.459065124999995, -2.6111648, 51.45916595]
#     - Distance: 17.283440724227724
#     - New values: climb=0.28214263916015625, angle=0.94
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6111648, 51.45916595, -2.61128375, 51.459266775]
#     - Distance: 17.283440724227724
#     - New values: climb=-0.0230712890625, angle=-0.08
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61128375, 51.459266775, -2.6114027, 51.4593676]
#     - Distance: 17.283440724227724
#     - New values: climb=0.11810302734375, angle=0.39
#   Group summary: 5 sections, 4 sections fixed
#
# Processing group: path179
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6109269, 51.4589643, -2.6107991, 51.4588512]
#     - Distance: 18.91803112306415
#     - New values: climb=0.9344940185546946, angle=2.83
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6107991, 51.4588512, -2.6106713, 51.4587381]
#     - Distance: 18.91803112306415
#     - New values: climb=-0.08437347412110086, angle=-0.26
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6106713, 51.4587381, -2.6105435, 51.458625]
#     - Distance: 18.91803112306415
#     - New values: climb=-0.132904052734375, angle=-0.4
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6105435, 51.458625, -2.6104157, 51.4585119]
#     - Distance: 18.91803112306415
#     - New values: climb=0.42243576049803977, angle=1.28
#   Group summary: 5 sections, 4 sections fixed
#
# Processing group: path180
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path181
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6097461, 51.4594533, -2.6098937, 51.459392175]
#     - Distance: 17.68001481339341
#     - New values: climb=0.0941009521484446, angle=0.3
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6098937, 51.459392175, -2.6100413000000002, 51.45933105]
#     - Distance: 17.68001481339341
#     - New values: climb=0.18312454223631391, angle=0.59
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6100413000000002, 51.45933105, -2.6101889000000003, 51.459269925]
#     - Distance: 17.68001481339341
#     - New values: climb=0.333568572998054, angle=1.08
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6101889000000003, 51.459269925, -2.6103365, 51.4592088]
#     - Distance: 17.68001481339341
#     - New values: climb=0.5210342407226562, angle=1.69
#   Fixing section1_4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6103365, 51.4592088, -2.6104841, 51.459147675]
#     - Distance: 17.68001481339341
#     - New values: climb=0.23052978515625, angle=0.75
#   Fixing section1_5:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6104841, 51.459147675, -2.6106317, 51.459086549999995]
#     - Distance: 17.68001481339341
#     - New values: climb=-0.12051010131835938, angle=-0.39
#   Fixing section1_6:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6106317, 51.459086549999995, -2.6107793, 51.459025425]
#     - Distance: 17.68001481339341
#     - New values: climb=-0.21498489379882812, angle=-0.7
#   Fixing section1_7:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6107793, 51.459025425, -2.6109269, 51.4589643]
#     - Distance: 17.68001481339341
#     - New values: climb=0.47454071044921875, angle=1.54
#   Group summary: 8 sections, 8 sections fixed
#
# Processing group: path182
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6097461, 51.4594533, -2.609879125, 51.4595658]
#     - Distance: 19.310138855873113
#     - New values: climb=1.01220703125, angle=3.0
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.609879125, 51.4595658, -2.61001215, 51.4596783]
#     - Distance: 19.310138855873113
#     - New values: climb=0.2689018249511719, angle=0.8
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61001215, 51.4596783, -2.6101451750000004, 51.4597908]
#     - Distance: 19.310138855873113
#     - New values: climb=-0.3456916809082031, angle=-1.03
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6101451750000004, 51.4597908, -2.6102782, 51.4599033]
#     - Distance: 19.310138855873113
#     - New values: climb=0.1635589599609304, angle=0.49
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6102782, 51.4599033, -2.61043965, 51.459836725]
#     - Distance: 19.32682256074863
#     - New values: climb=-0.1695556640625, angle=-0.5
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61043965, 51.459836725, -2.6106011000000002, 51.45977015]
#     - Distance: 19.32682256074863
#     - New values: climb=0.43103408813477273, angle=1.28
#   Fixing section2_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6106011000000002, 51.45977015, -2.61076255, 51.459703575]
#     - Distance: 19.32682256074863
#     - New values: climb=0.5795974731445312, angle=1.72
#   Fixing section2_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61076255, 51.459703575, -2.610924, 51.459637]
#     - Distance: 19.32682256074863
#     - New values: climb=-0.25760650634764914, angle=-0.76
#   Group summary: 8 sections, 8 sections fixed
#
# Processing group: path183
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6092836, 51.4590048, -2.6094387571428572, 51.458937014285716]
#     - Distance: 18.739712719256897
#     - New values: climb=0.04059600830079546, angle=0.12
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6094387571428572, 51.458937014285716, -2.609593914285714, 51.45886922857143]
#     - Distance: 18.739712719256897
#     - New values: climb=0.20838165283203125, angle=0.64
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.609593914285714, 51.45886922857143, -2.6097490714285714, 51.458801442857144]
#     - Distance: 18.739712719256897
#     - New values: climb=0.7865676879882741, angle=2.4
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6097490714285714, 51.458801442857144, -2.6099042285714287, 51.45873365714286]
#     - Distance: 18.739712719256897
#     - New values: climb=1.0386314392089844, angle=3.17
#   Fixing section1_4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6099042285714287, 51.45873365714286, -2.610059385714286, 51.45866587142857]
#     - Distance: 18.739712719256897
#     - New values: climb=0.19185638427735086, angle=0.59
#   Fixing section1_5:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.610059385714286, 51.45866587142857, -2.610214542857143, 51.458598085714286]
#     - Distance: 18.739712719256897
#     - New values: climb=0.26251220703125, angle=0.8
#   Fixing section1_6:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.610214542857143, 51.458598085714286, -2.6103697, 51.4585303]
#     - Distance: 18.739712719256897
#     - New values: climb=-0.35322952270508523, angle=-1.08
#   Group summary: 8 sections, 7 sections fixed
#
# Processing group: path184
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6092865, 51.4590233, -2.60939415, 51.459133675]
#     - Distance: 17.09829631407288
#     - New values: climb=-0.12464141845703125, angle=-0.42
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60939415, 51.459133675, -2.6095018000000003, 51.459244049999995]
#     - Distance: 17.09829631407288
#     - New values: climb=0.12583541870117188, angle=0.42
#   Fixing section2_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6095018000000003, 51.459244049999995, -2.60960945, 51.459354425]
#     - Distance: 17.09829631407288
#     - New values: climb=0.19986724853514914, angle=0.67
#   Fixing section2_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60960945, 51.459354425, -2.6097171, 51.4594648]
#     - Distance: 17.09829631407288
#     - New values: climb=-0.47928619384764914, angle=-1.61
#   Group summary: 5 sections, 4 sections fixed
#
# Processing group: path185
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path186
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6114027, 51.4593676, -2.61128375, 51.459266775]
#     - Distance: 17.283440724227724
#     - New values: climb=-0.11810302734375, angle=-0.39
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61128375, 51.459266775, -2.6111648, 51.45916595]
#     - Distance: 17.283440724227724
#     - New values: climb=0.0230712890625, angle=0.08
#   Fixing section2_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6111648, 51.45916595, -2.61104585, 51.459065124999995]
#     - Distance: 17.283440724227724
#     - New values: climb=-0.28214263916015625, angle=-0.94
#   Fixing section2_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61104585, 51.459065124999995, -2.6109269, 51.4589643]
#     - Distance: 17.283440724227724
#     - New values: climb=-0.7593955993652344, angle=-2.52
#   Group summary: 5 sections, 4 sections fixed
#
# Processing group: path187
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6114487, 51.4594291, -2.611551066666667, 51.459524466666664]
#     - Distance: 15.511235603831354
#     - New values: climb=0.5405235290527344, angle=2.0
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611551066666667, 51.459524466666664, -2.611653433333333, 51.459619833333335]
#     - Distance: 15.511235603831354
#     - New values: climb=0.13959503173828125, angle=0.52
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611653433333333, 51.459619833333335, -2.6117558, 51.4597152]
#     - Distance: 15.511235603831354
#     - New values: climb=-0.07379913330078125, angle=-0.27
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6117558, 51.4597152, -2.611910266666667, 51.45965786666667]
#     - Distance: 18.23156253806936
#     - New values: climb=-0.08012008666992898, angle=-0.25
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611910266666667, 51.45965786666667, -2.6120647333333333, 51.45960053333333]
#     - Distance: 18.23156253806936
#     - New values: climb=-0.15598297119139914, angle=-0.49
#   Fixing section2_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6120647333333333, 51.45960053333333, -2.6122192, 51.4595432]
#     - Distance: 18.23156253806936
#     - New values: climb=-0.07750701904296875, angle=-0.24
#   Group summary: 6 sections, 6 sections fixed
#
# Processing group: path188
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6114487, 51.4594291, -2.6113416000000003, 51.45947195]
#     - Distance: 12.765466619771662
#     - New values: climb=-0.24619293212889914, angle=-1.1
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6113416000000003, 51.45947195, -2.6112345, 51.4595148]
#     - Distance: 12.765466619771662
#     - New values: climb=-0.09492492675782671, angle=-0.43
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6112345, 51.4595148, -2.6111242, 51.45955825]
#     - Distance: 13.118829442825895
#     - New values: climb=-0.12665939331053977, angle=-0.55
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6111242, 51.45955825, -2.6110139, 51.4596017]
#     - Distance: 13.118829442825895
#     - New values: climb=-0.21555328369140625, angle=-0.94
#   Group summary: 5 sections, 4 sections fixed
#
# Processing group: path189
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.610924, 51.459637, -2.61076255, 51.459703575]
#     - Distance: 19.32682256074863
#     - New values: climb=0.25760650634764914, angle=0.76
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61076255, 51.459703575, -2.6106011000000002, 51.45977015]
#     - Distance: 19.32682256074863
#     - New values: climb=-0.5795974731445312, angle=-1.72
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6106011000000002, 51.45977015, -2.61043965, 51.459836725]
#     - Distance: 19.32682256074863
#     - New values: climb=-0.43103408813477273, angle=-1.28
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61043965, 51.459836725, -2.6102782, 51.4599033]
#     - Distance: 19.32682256074863
#     - New values: climb=0.1695556640625, angle=0.5
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6102782, 51.4599033, -2.6101451750000004, 51.4597908]
#     - Distance: 19.310138855873113
#     - New values: climb=-0.1635589599609304, angle=-0.49
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6101451750000004, 51.4597908, -2.61001215, 51.4596783]
#     - Distance: 19.310138855873113
#     - New values: climb=0.3456916809082031, angle=1.03
#   Fixing section2_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61001215, 51.4596783, -2.609879125, 51.4595658]
#     - Distance: 19.310138855873113
#     - New values: climb=-0.2689018249511719, angle=-0.8
#   Fixing section2_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.609879125, 51.4595658, -2.6097461, 51.4594533]
#     - Distance: 19.310138855873113
#     - New values: climb=-1.01220703125, angle=-3.0
#   Group summary: 8 sections, 8 sections fixed
#
# Processing group: path190
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6110139, 51.4596017, -2.6111242, 51.45955825]
#     - Distance: 13.118829442825895
#     - New values: climb=0.21555328369140625, angle=0.94
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6111242, 51.45955825, -2.6112345, 51.4595148]
#     - Distance: 13.118829442825895
#     - New values: climb=0.12665939331053977, angle=0.55
#   Fixing section3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6112345, 51.4595148, -2.6113416000000003, 51.45947195]
#     - Distance: 12.765466619771662
#     - New values: climb=0.09492492675782671, angle=0.43
#   Fixing section3_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6113416000000003, 51.45947195, -2.6114487, 51.4594291]
#     - Distance: 12.765466619771662
#     - New values: climb=0.24619293212889914, angle=1.1
#   Group summary: 5 sections, 4 sections fixed
#
# Processing group: path191
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6139731, 51.4602441, -2.6138098833333334, 51.46027813333333]
#     - Distance: 18.440494503545185
#     - New values: climb=-0.431854248046875, angle=-1.34
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6138098833333334, 51.46027813333333, -2.6136466666666665, 51.46031216666667]
#     - Distance: 18.440494503545185
#     - New values: climb=-0.66265869140625, angle=-2.06
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6136466666666665, 51.46031216666667, -2.61348345, 51.460346200000004]
#     - Distance: 18.440494503545185
#     - New values: climb=-0.393951416015625, angle=-1.22
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61348345, 51.460346200000004, -2.6133202333333334, 51.46038023333333]
#     - Distance: 18.440494503545185
#     - New values: climb=-0.8102798461914062, angle=-2.52
#   Fixing section1_4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6133202333333334, 51.46038023333333, -2.6131570166666664, 51.46041426666667]
#     - Distance: 18.440494503545185
#     - New values: climb=-0.145751953125, angle=-0.45
#   Fixing section1_5:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6131570166666664, 51.46041426666667, -2.6129938, 51.4604483]
#     - Distance: 18.440494503545185
#     - New values: climb=-0.04184722900390625, angle=-0.13
#   Group summary: 6 sections, 6 sections fixed
#
# Processing group: path192
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140139, 51.4601088, -2.6140172, 51.45995475]
#     - Distance: 17.134928436913988
#     - New values: climb=-0.55169677734375, angle=-1.84
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140172, 51.45995475, -2.6140205, 51.4598007]
#     - Distance: 17.134928436913988
#     - New values: climb=-1.6004104614257812, angle=-5.34
#   Group summary: 3 sections, 2 sections fixed
#
# Processing group: path193
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140205, 51.4598007, -2.6140147666666667, 51.4596481]
#     - Distance: 16.9816344207827
#     - New values: climb=-0.18073272705078125, angle=-0.61
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140147666666667, 51.4596481, -2.6140090333333332, 51.4594955]
#     - Distance: 16.9816344207827
#     - New values: climb=-0.12348175048828125, angle=-0.42
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140090333333332, 51.4594955, -2.6140033000000003, 51.4593429]
#     - Distance: 16.9816344207827
#     - New values: climb=-0.27350616455078125, angle=-0.92
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140033000000003, 51.4593429, -2.613997566666667, 51.4591903]
#     - Distance: 16.9816344207827
#     - New values: climb=-0.49417877197265625, angle=-1.67
#   Fixing section1_4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.613997566666667, 51.4591903, -2.6139918333333334, 51.4590377]
#     - Distance: 16.9816344207827
#     - New values: climb=-0.34429931640625, angle=-1.16
#   Fixing section1_5:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6139918333333334, 51.4590377, -2.6139861, 51.4588851]
#     - Distance: 16.9816344207827
#     - New values: climb=-0.6139144897461009, angle=-2.07
#   Group summary: 6 sections, 6 sections fixed
#
# Processing group: path194
#   Fixing section9:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6137147, 51.4590033, -2.6138504, 51.458944200000005]
#     - Distance: 16.381419082403376
#     - New values: climb=0.015651702880859375, angle=0.05
#   Fixing section9_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6138504, 51.458944200000005, -2.6139861, 51.4588851]
#     - Distance: 16.381419082403376
#     - New values: climb=0.016670227050774145, angle=0.06
#   Group summary: 10 sections, 2 sections fixed
#
# Processing group: path195
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140205, 51.4598007, -2.6140172, 51.45995475]
#     - Distance: 17.134928436913988
#     - New values: climb=1.6004104614257812, angle=5.34
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140172, 51.45995475, -2.6140139, 51.4601088]
#     - Distance: 17.134928436913988
#     - New values: climb=0.55169677734375, angle=1.84
#   Group summary: 3 sections, 2 sections fixed
#
# Processing group: path196
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6139861, 51.4588851, -2.6139918333333334, 51.4590377]
#     - Distance: 16.9816344207827
#     - New values: climb=0.6139144897461009, angle=2.07
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6139918333333334, 51.4590377, -2.613997566666667, 51.4591903]
#     - Distance: 16.9816344207827
#     - New values: climb=0.34429931640625, angle=1.16
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.613997566666667, 51.4591903, -2.6140033000000003, 51.4593429]
#     - Distance: 16.9816344207827
#     - New values: climb=0.49417877197265625, angle=1.67
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140033000000003, 51.4593429, -2.6140090333333332, 51.4594955]
#     - Distance: 16.9816344207827
#     - New values: climb=0.27350616455078125, angle=0.92
#   Fixing section1_4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140090333333332, 51.4594955, -2.6140147666666667, 51.4596481]
#     - Distance: 16.9816344207827
#     - New values: climb=0.12348175048828125, angle=0.42
#   Fixing section1_5:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6140147666666667, 51.4596481, -2.6140205, 51.4598007]
#     - Distance: 16.9816344207827
#     - New values: climb=0.18073272705078125, angle=0.61
#   Group summary: 6 sections, 6 sections fixed
#
# Processing group: path197
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6139861, 51.4588851, -2.6138504, 51.458944200000005]
#     - Distance: 16.381419082403376
#     - New values: climb=-0.016670227050774145, angle=-0.06
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6138504, 51.458944200000005, -2.6137147, 51.4590033]
#     - Distance: 16.381419082403376
#     - New values: climb=-0.015651702880859375, angle=-0.05
#   Group summary: 10 sections, 2 sections fixed
#
# Processing group: path198
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6139861, 51.4588851, -2.6139712333333334, 51.4587571]
#     - Distance: 14.328780660816593
#     - New values: climb=0.32755279541016336, angle=1.31
#   Fixing section1_1:
# ...
#     - Distance: 10.285264719645069
#     - New values: climb=0.025299072265625, angle=0.14
#   Fixing section4_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6021155499999997, 51.4590152, -2.6020269, 51.4590432]
#     - Distance: 10.285264719645069
#     - New values: climb=-0.26444244384765625, angle=-1.47
#   Group summary: 5 sections, 2 sections fixed
#
# Processing group: path700
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6019891, 51.4590198, -2.60186385, 51.459059350000004]
#     - Distance: 14.531295896049771
#     - New values: climb=-0.1273040771484375, angle=-0.5
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60186385, 51.459059350000004, -2.6017386, 51.4590989]
#     - Distance: 14.531295896049771
#     - New values: climb=-0.15813446044921875, angle=-0.62
#   Group summary: 2 sections, 2 sections fixed
#
# Processing group: path701
#   Group summary: 10 sections, 0 sections fixed
#
# Processing group: path702
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path703
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6014293, 51.4599593, -2.6015758499999997, 51.45991155]
#     - Distance: 17.052819474662343
#     - New values: climb=0.149932861328125, angle=0.5
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6015758499999997, 51.45991155, -2.6017224, 51.4598638]
#     - Distance: 17.052819474662343
#     - New values: climb=0.10230255126953125, angle=0.34
#   Group summary: 2 sections, 2 sections fixed
#
# Processing group: path704
#   Group summary: 5 sections, 0 sections fixed
#
# Processing group: path705
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6014092, 51.4599352, -2.60134175, 51.459854449999995]
#     - Distance: 11.673270018214101
#     - New values: climb=0.5086288452148438, angle=2.49
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60134175, 51.459854449999995, -2.6012743, 51.4597737]
#     - Distance: 11.673270018214101
#     - New values: climb=0.11737823486328125, angle=0.58
#   Group summary: 3 sections, 2 sections fixed
#
# Processing group: path706
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6012743, 51.4597737, -2.60134175, 51.459854449999995]
#     - Distance: 11.673270018214101
#     - New values: climb=-0.11737823486328125, angle=-0.58
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60134175, 51.459854449999995, -2.6014092, 51.4599352]
#     - Distance: 11.673270018214101
#     - New values: climb=-0.5086288452148438, angle=-2.49
#   Group summary: 3 sections, 2 sections fixed
#
# Processing group: path707
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.602205, 51.4597103, -2.6023295500000003, 51.459670700000004]
#     - Distance: 14.459233934637506
#     - New values: climb=-0.1219024658203125, angle=-0.48
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6023295500000003, 51.459670700000004, -2.6024541, 51.4596311]
#     - Distance: 14.459233934637506
#     - New values: climb=-0.048858642578125, angle=-0.19
#   Group summary: 3 sections, 2 sections fixed
#
# Processing group: path708
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6021477, 51.4597285, -2.6020059333333334, 51.4597736]
#     - Distance: 16.458830820081904
#     - New values: climb=0.09568023681640625, angle=0.33
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6020059333333334, 51.4597736, -2.6018641666666666, 51.4598187]
#     - Distance: 16.458830820081904
#     - New values: climb=0.05731964111328125, angle=0.2
#   Fixing section2_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6018641666666666, 51.4598187, -2.6017224, 51.4598638]
#     - Distance: 16.458830820081904
#     - New values: climb=-0.22119140625, angle=-0.77
#   Group summary: 4 sections, 3 sections fixed
#
# Processing group: path709
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path710
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path711
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path712
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6024541, 51.4596311, -2.60256695, 51.45959525000001]
#     - Distance: 13.099942355366476
#     - New values: climb=0.40517425537109375, angle=1.77
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60256695, 51.45959525000001, -2.6026798, 51.4595594]
#     - Distance: 13.099942355366476
#     - New values: climb=-0.206329345703125, angle=-0.9
#   Group summary: 2 sections, 2 sections fixed
#
# Processing group: path713
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6024541, 51.4596311, -2.6023295500000003, 51.459670700000004]
#     - Distance: 14.459233934637506
#     - New values: climb=0.048858642578125, angle=0.19
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6023295500000003, 51.459670700000004, -2.602205, 51.4597103]
#     - Distance: 14.459233934637506
#     - New values: climb=0.1219024658203125, angle=0.48
#   Group summary: 3 sections, 2 sections fixed
#
# Processing group: path714
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path715
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6030647, 51.4590239, -2.60312915, 51.4591058]
#     - Distance: 11.564595269869315
#     - New values: climb=-0.43827056884765625, angle=-2.17
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60312915, 51.4591058, -2.6031936, 51.4591877]
#     - Distance: 11.564595269869315
#     - New values: climb=-0.43819427490234375, angle=-2.17
#   Group summary: 7 sections, 2 sections fixed
#
# Processing group: path716
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6030304, 51.4594522, -2.6029135333333335, 51.459487933333335]
#     - Distance: 13.519880311964435
#     - New values: climb=0.23351287841796875, angle=0.99
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6029135333333335, 51.459487933333335, -2.602796666666667, 51.45952366666667]
#     - Distance: 13.519880311964435
#     - New values: climb=0.135833740234375, angle=0.58
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.602796666666667, 51.45952366666667, -2.6026798, 51.4595594]
#     - Distance: 13.519880311964435
#     - New values: climb=0.069183349609375, angle=0.29
#   Group summary: 3 sections, 3 sections fixed
#
# Processing group: path717
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path718
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path719
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6029439, 51.4593484, -2.6028217000000002, 51.45938793333333]
#     - Distance: 14.209648593124868
#     - New values: climb=0.28964996337890625, angle=1.17
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6028217000000002, 51.45938793333333, -2.6026995, 51.45942746666667]
#     - Distance: 14.209648593124868
#     - New values: climb=0.21807098388671875, angle=0.88
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6026995, 51.45942746666667, -2.6025773, 51.459467]
#     - Distance: 14.209648593124868
#     - New values: climb=0.0468292236328125, angle=0.19
#   Group summary: 3 sections, 3 sections fixed
#
# Processing group: path720
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6029439, 51.4593484, -2.60305175, 51.4593135]
#     - Distance: 12.541315617757023
#     - New values: climb=-0.49823760986328125, angle=-2.28
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60305175, 51.4593135, -2.6031596, 51.4592786]
#     - Distance: 12.541315617757023
#     - New values: climb=-0.5781707763671875, angle=-2.64
#   Group summary: 2 sections, 2 sections fixed
#
# Processing group: path721
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path722
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6025773, 51.459467, -2.6026995, 51.45942746666667]
#     - Distance: 14.209648593124868
#     - New values: climb=-0.0468292236328125, angle=-0.19
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6026995, 51.45942746666667, -2.6028217000000002, 51.45938793333333]
#     - Distance: 14.209648593124868
#     - New values: climb=-0.21807098388671875, angle=-0.88
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6028217000000002, 51.45938793333333, -2.6029439, 51.4593484]
#     - Distance: 14.209648593124868
#     - New values: climb=-0.28964996337890625, angle=-1.17
#   Group summary: 3 sections, 3 sections fixed
#
# Processing group: path723
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6031596, 51.4592786, -2.60305175, 51.4593135]
#     - Distance: 12.541315617757023
#     - New values: climb=0.5781707763671875, angle=2.64
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60305175, 51.4593135, -2.6029439, 51.4593484]
#     - Distance: 12.541315617757023
#     - New values: climb=0.49823760986328125, angle=2.28
#   Group summary: 2 sections, 2 sections fixed
#
# Processing group: path724
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6033435, 51.4593565, -2.603490625, 51.459311549999995]
#     - Distance: 17.01920723655718
#     - New values: climb=-0.858489990234375, angle=-2.89
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.603490625, 51.459311549999995, -2.60363775, 51.4592666]
#     - Distance: 17.01920723655718
#     - New values: climb=-0.35831451416015625, angle=-1.21
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60363775, 51.4592666, -2.6037848749999997, 51.45922165]
#     - Distance: 17.01920723655718
#     - New values: climb=-0.5874710083007812, angle=-1.98
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6037848749999997, 51.45922165, -2.603932, 51.4591767]
#     - Distance: 17.01920723655718
#     - New values: climb=-0.5731353759765625, angle=-1.93
#   Group summary: 5 sections, 4 sections fixed
#
# Processing group: path725
#   Group summary: 2 sections, 0 sections fixed
#
# Processing group: path726
#   Fixing section6:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6031936, 51.4591877, -2.60312915, 51.4591058]
#     - Distance: 11.564595269869315
#     - New values: climb=0.43819427490234375, angle=2.17
#   Fixing section6_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60312915, 51.4591058, -2.6030647, 51.4590239]
#     - Distance: 11.564595269869315
#     - New values: climb=0.43827056884765625, angle=2.17
#   Group summary: 7 sections, 2 sections fixed
#
# Processing group: path727
#   Fixing section4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6090571, 51.4520706, -2.6089206, 51.45215105]
#     - Distance: 17.54589738613186
#     - New values: climb=-2.08016204833984, angle=-6.76
#   Fixing section4_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6089206, 51.45215105, -2.6087841, 51.4522315]
#     - Distance: 17.54589738613186
#     - New values: climb=-0.6822853088378906, angle=-2.23
#   Group summary: 5 sections, 2 sections fixed
#
# Processing group: path728
#   Fixing section3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6089698, 51.4523419, -2.6090652, 51.4523953]
#     - Distance: 12.10559355829663
#     - New values: climb=2.008319854736328, angle=9.42
#   Fixing section3_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6090652, 51.4523953, -2.6091606, 51.4524487]
#     - Distance: 12.10559355829663
#     - New values: climb=-0.22954559326171875, angle=-1.09
#   Fixing section4:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6091606, 51.4524487, -2.60928605, 51.45252315]
#     - Distance: 16.154655001152676
#     - New values: climb=1.1226539611816406, angle=3.98
#   Fixing section4_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60928605, 51.45252315, -2.6094115, 51.4525976]
#     - Distance: 16.154655001152676
#     - New values: climb=2.647342681884769, angle=9.31
#   Group summary: 12 sections, 4 sections fixed
#
# Processing group: path729
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6087841, 51.4522315, -2.6089206, 51.45215105]
#     - Distance: 17.54589738613186
#     - New values: climb=0.6822853088378906, angle=2.23
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6089206, 51.45215105, -2.6090571, 51.4520706]
#     - Distance: 17.54589738613186
#     - New values: climb=2.08016204833984, angle=6.76
#   Group summary: 5 sections, 2 sections fixed
#
# Processing group: path730
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path731
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6097171, 51.4594648, -2.60960945, 51.459354425]
#     - Distance: 17.09829631407288
#     - New values: climb=0.47928619384764914, angle=1.61
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60960945, 51.459354425, -2.6095018000000003, 51.459244049999995]
#     - Distance: 17.09829631407288
#     - New values: climb=-0.19986724853514914, angle=-0.67
#   Fixing section1_2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6095018000000003, 51.459244049999995, -2.60939415, 51.459133675]
#     - Distance: 17.09829631407288
#     - New values: climb=-0.12583541870117188, angle=-0.42
#   Fixing section1_3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60939415, 51.459133675, -2.6092865, 51.4590233]
#     - Distance: 17.09829631407288
#     - New values: climb=0.12464141845703125, angle=0.42
#   Group summary: 5 sections, 4 sections fixed
#
# Processing group: path732
#   Fixing section1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6097171, 51.4594648, -2.60959435, 51.4595137]
#     - Distance: 14.622062729174806
#     - New values: climb=0.2344818115234446, angle=0.92
#   Fixing section1_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.60959435, 51.4595137, -2.6094716, 51.4595626]
#     - Distance: 14.622062729174806
#     - New values: climb=0.499622344970696, angle=1.96
#   Fixing section2:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6094716, 51.4595626, -2.6093086999999997, 51.45961845]
#     - Distance: 19.053591928133912
#     - New values: climb=-0.21441268920899148, angle=-0.64
#   Fixing section2_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.6093086999999997, 51.45961845, -2.6091458, 51.4596743]
#     - Distance: 19.053591928133912
#     - New values: climb=-0.5309181213378906, angle=-1.6
#   Group summary: 8 sections, 4 sections fixed
#
# Processing group: path733
#   Group summary: 1 sections, 0 sections fixed
#
# Processing group: path734
#   Fixing section3:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.611963, 51.4551776, -2.61190365, 51.4550955]
#     - Distance: 11.243858393609996
#     - New values: climb=-0.0815277099609375, angle=-0.42
#   Fixing section3_1:
#     - Original data: climb=False, angle=False
#     - Coords: [-2.61190365, 51.4550955, -2.6118443, 51.4550134]
#     - Distance: 11.243858393609996
#     - New values: climb=-0.799072265625, angle=-4.07
#   Group summary: 4 sections, 2 sections fixed
#
# Processing group: path735
#   Group summary: 4 sections, 0 sections fixed
#
# Saving updated data to '../data/fixed_analysed_dis_data.json'...
#
# Processing complete!
# Total sections: 3477
# Sections with missing data: 1278
# Sections successfully processed: 1278
# Success rate: 100.00%
