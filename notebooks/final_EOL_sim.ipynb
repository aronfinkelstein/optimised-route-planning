# %% [markdown]
# # Final Simulation of Singular Routes

# %%
import main_1 as m
import models.road_network.create_graph as cg
import models.vehicle_models.battery_deg as bd
import scipy.stats as stats
import random

import json
from pprint import pprint
import matplotlib.pyplot as plt
import simulation.simulate_routes as sr
import datetime
import os
import numpy as np

# %%
road_network_file, road_df, static_data, vehicle_data, battery_data, map_data, weights = m.import_data()

# %%
OCV = battery_data["OCV"]
capacity = battery_data["Capacity"]
R_int = battery_data["R_internal"]
motor_eff = vehicle_data["motor_eff"]
graph = cg.create_osmnx_compatible_graph(road_network_file, debug = False)

# %%
with open("test_data/test_route_set.json", "r") as file:
        test_routes_dict = json.load(file)

# %% [markdown]
# Simulate a cycle of charge - down to 80% DoD

# %%
def find_next_capacity(start_cap, consumption):
        loss = consumption/OCV
        cap = start_cap - loss
        return cap

# %%
import random

def simulate_full_discharge(sim_results, initial_capacity):
    results_dict = {}
    cap_loss_distance = []
    battery_capacity = []
    distance_travelled = []

    # Initialize with your starting capacity
    current_capacity = initial_capacity  # Use your initial capacity value

    # Create a list of all routes to process
    all_routes = []
    for key, values in sim_results.items():
        for test, test_data in values.items():
            if 'distance' in test:
                for id, item in test_data.items():
                    all_routes.append((key, test, test_data))
                    break
    # Shuffle the routes randomly
    random.shuffle(all_routes)

    # Process routes one by one until capacity drops below threshold
    route_index = 0
    while current_capacity >= capacity * 0.2 and route_index < len(all_routes):
        key, test, test_data = all_routes[route_index]
        
        # Initialize dictionary entries if needed
        if key not in results_dict:
            results_dict[key] = {}
        results_dict[key][test] = {}
        
        # Calculate capacity loss using the current capacity value
        capacity_loss = bd.route_analysis(
            test_data['detailed_results'], 
            test_data['current_list'], 
            test_data['consumptions'],
            OCV, 
            current_capacity,
            base_k = 0.2,
            c_rate_exp = 0.2286
        )
        # Store results
        cap_loss_distance.append(capacity_loss)
        results_dict[key][test]['capacity_loss'] = capacity_loss
        results_dict[key][test]['consumption'] = test_data['total_consumption']

        distance_travelled.append(test_data['total_distance'])

        # Update capacity for the next route
        current_capacity = find_next_capacity(current_capacity, test_data['total_consumption'])
        battery_capacity.append(current_capacity)
        
        # Move to next route
        route_index += 1
    
    return results_dict, current_capacity, cap_loss_distance

# %%
with open("results/singular_routes_sim/simulation_test_set1.json", "r") as file:
    sim_results = json.load(file)


results_dict, current_capacity, cap_loss_distance = simulate_full_discharge(sim_results, capacity)
print(sum(cap_loss_distance))

# %%
def simulate_cycles(initial_capacity):
    cap  = initial_capacity
    losses = []
    deg = []

    for i in range(600):
        results_dict, current_capacity, cap_loss_distance = simulate_full_discharge(sim_results, cap)

        cap -= sum(cap_loss_distance)
        losses.append(sum(cap_loss_distance))
        deg.append(cap)
    return deg, losses
    
degradation, losses = simulate_cycles(capacity)

# %%
print(len(losses))
print(np.average(losses))
print(sum(losses))
plt.plot(range(len(degradation)), degradation)
plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

def get_routes_sequence(sim_results, route_type="distance"):
    """
    Extract and randomly shuffle routes of a specific type from sim_results.
    
    Parameters:
    sim_results (dict): Dictionary containing all simulation results
    route_type (str): Type of routes to extract (e.g., 'distance', 'optimised')
    
    Returns:
    list: Shuffled list of route tuples (key, test, test_data)
    """
    all_routes = []
    
    for key, values in sim_results.items():
        for test, test_data in values.items():
            if route_type in test:
                for id, item in test_data.items():
                    all_routes.append((key, test, test_data))
                    break
    
    # Shuffle the routes randomly
    random.shuffle(all_routes)
    return all_routes

def simulate_discharge_for_route_type(sim_results, initial_capacity, route_type="distance", seed=None):
    """
    Simulate battery discharge for a specific route type.
    
    Parameters:
    sim_results (dict): Dictionary containing all simulation results
    initial_capacity (float): Initial battery capacity
    route_type (str): Type of routes to use (e.g., 'distance', 'optimised')
    seed (int): Random seed for route shuffling (None for random, value for deterministic)
    
    Returns:
    tuple: (results_dict, final_capacity, cap_loss_list, battery_capacity_list, distance_travelled_list)
    """
    results_dict = {}
    cap_loss_list = []
    battery_capacity = []
    distance_travelled = []
    
    # Set random seed if provided
    if seed is not None:
        random.seed(seed)
    
    # Get routes for this simulation
    all_routes = get_routes_sequence(sim_results, route_type)
    
    # Initialize with starting capacity
    current_capacity = initial_capacity
    
    # Process routes one by one until capacity drops below threshold
    route_index = 0
    while current_capacity >= initial_capacity * 0.2 and route_index < len(all_routes):
        key, test, test_data = all_routes[route_index]
        
        # Initialize dictionary entries if needed
        if key not in results_dict:
            results_dict[key] = {}
        results_dict[key][test] = {}
        
        # Calculate capacity loss using the current capacity value
        capacity_loss = 2 * bd.route_analysis(
            test_data['detailed_results'], 
            test_data['current_list'], 
            test_data['consumptions'],
            OCV, 
            current_capacity,
            base_k = 0.012,
            c_rate_exp = 0.8
        )
        
        # Store results
        cap_loss_list.append(capacity_loss)
        results_dict[key][test]['capacity_loss'] = capacity_loss
        results_dict[key][test]['consumption'] = test_data['total_consumption']
        distance_travelled.append(test_data['total_distance'])
        
        # Update capacity for the next route
        current_capacity = find_next_capacity(current_capacity, test_data['total_consumption'])
        battery_capacity.append(current_capacity)
        
        # Move to next route
        route_index += 1
    
    return results_dict, current_capacity, cap_loss_list, battery_capacity, distance_travelled

def compare_discharge_simulations(sim_results, regular_capacity, optimised_capacity):
    """
    Compare battery discharge for both regular and optimized routes using the same random sequence.
    
    Parameters:
    sim_results (dict): Dictionary containing all simulation results
    regular_capacity (float): Current capacity for regular routes simulation
    optimised_capacity (float): Current capacity for optimised routes simulation
    
    Returns:
    dict: Combined results from both simulations
    """
    # Use a fixed seed for reproducibility and to ensure both simulations use the same random sequence
    random_seed = random.randint(0, 9999)
    
    # Run simulation for regular distance routes
    results_dict_regular, final_capacity_regular, cap_loss_regular, \
    battery_capacity_regular, distance_travelled_regular = simulate_discharge_for_route_type(
        sim_results, regular_capacity, route_type="distance", seed=random_seed
    )
    
    # Run simulation for optimised routes with the same seed
    results_dict_optimised, final_capacity_optimised, cap_loss_optimised, \
    battery_capacity_optimised, distance_travelled_optimised = simulate_discharge_for_route_type(
        sim_results, optimised_capacity, route_type="optimised", seed=random_seed
    )
    
    # Combine results for comparison
    comparison_results = {
        'regular': {
            'results_dict': results_dict_regular,
            'final_capacity': final_capacity_regular,
            'cap_loss_list': cap_loss_regular,
            'battery_capacity': battery_capacity_regular,
            'distance_travelled': distance_travelled_regular,
        },
        'optimised': {
            'results_dict': results_dict_optimised,
            'final_capacity': final_capacity_optimised,
            'cap_loss_list': cap_loss_optimised,
            'battery_capacity': battery_capacity_optimised,
            'distance_travelled': distance_travelled_optimised,
        }
    }
    
    return comparison_results

# Simulate multiple battery discharge cycles and track degradation
def simulate_cycles(sim_results, initial_capacity, num_cycles=600):
    """
    Simulate multiple battery discharge cycles, tracking degradation over time.
    
    Parameters:
    sim_results (dict): Dictionary containing all simulation results
    initial_capacity (float): Initial battery capacity
    num_cycles (int): Number of cycles to simulate
    
    Returns:
    tuple: (degradation_data, losses_data)
        - degradation_data: Dictionary with capacity over time for regular and optimized routes
        - losses_data: Dictionary with capacity losses for each cycle
    """
    # Initialize tracking variables
    regular_capacity = initial_capacity
    optimised_capacity = initial_capacity
    
    regular_degradation = [regular_capacity]
    optimised_degradation = [optimised_capacity]
    
    regular_losses = []
    optimised_losses = []
    
    cycle_numbers = [0]
    
    # Track termination status for each battery type
    regular_terminated = False
    optimised_terminated = False
    
    for cycle in range(1, num_cycles + 1):
        # Run simulations for this cycle
        # If a battery has reached termination threshold, we still simulate but won't update its capacity further
        comparison_results = compare_discharge_simulations(
            sim_results, 
            regular_capacity if not regular_terminated else initial_capacity * 0.2,
            optimised_capacity if not optimised_terminated else initial_capacity * 0.2
        )
        
        # Accumulate losses from this cycle
        regular_cycle_loss = sum(comparison_results['regular']['cap_loss_list']) if not regular_terminated else 0
        optimised_cycle_loss = sum(comparison_results['optimised']['cap_loss_list']) if not optimised_terminated else 0
        
        # Update capacities only if not terminated
        if not regular_terminated:
            regular_capacity -= regular_cycle_loss
            # Check if regular has now reached termination
            if regular_capacity < 0.2 * initial_capacity:
                regular_capacity = 0.2 * initial_capacity  # Floor at 20%
                regular_terminated = True
                print(f"Regular routes battery terminated at cycle {cycle}")
        
        if not optimised_terminated:
            optimised_capacity -= optimised_cycle_loss
            # Check if optimised has now reached termination
            if optimised_capacity < 0.2 * initial_capacity:
                optimised_capacity = 0.2 * initial_capacity  # Floor at 20%
                optimised_terminated = True
                print(f"Optimised routes battery terminated at cycle {cycle}")
        
        # Store data for this cycle
        regular_degradation.append(regular_capacity)
        optimised_degradation.append(optimised_capacity)
        regular_losses.append(regular_cycle_loss)
        optimised_losses.append(optimised_cycle_loss)
        cycle_numbers.append(cycle)
        
        # Terminate simulation only when both batteries have reached end of life
        if regular_terminated and optimised_terminated:
            print(f"Both batteries terminated. Ending simulation at cycle {cycle}")
            break
    
    # Compile results
    degradation_data = {
        'cycles': cycle_numbers,
        'regular_capacity': regular_degradation,
        'optimised_capacity': optimised_degradation,
        'capacity_percentage_regular': [cap/initial_capacity*100 for cap in regular_degradation],
        'capacity_percentage_optimised': [cap/initial_capacity*100 for cap in optimised_degradation]
    }
    
    losses_data = {
        'cycles': cycle_numbers[1:],
        'regular_losses': regular_losses,
        'optimised_losses': optimised_losses
    }
    
    return degradation_data, losses_data

def plot_degradation_comparison(degradation_data):
    """
    Plot the battery degradation comparison between regular and optimized routes.
    
    Parameters:
    degradation_data (dict): Dictionary containing degradation data from simulate_cycles
    """
    plt.figure(figsize=(10, 6))
    plt.plot(degradation_data['cycles'], degradation_data['capacity_percentage_regular'], 'b-', label='Regular Routes')
    plt.plot(degradation_data['cycles'], degradation_data['capacity_percentage_optimised'], 'g-', label='Optimised Routes')
    plt.xlabel('Cycle Number')
    plt.ylabel('Remaining Capacity (%)')
    plt.title('Battery Degradation Comparison')
    plt.legend()
    plt.grid(True)
    plt.axhline(y=20, color='r', linestyle='--', label='End of Life (20%)')
    plt.savefig('battery_degradation_comparison.png')
    plt.show()

# %%
simulation1 = "results/singular_routes_sim/simulation_test_set1.json"
simulation2 = "results/singular_routes_sim/simulation_test_set2.json"
simulation3 = "results/singular_routes_sim/simulation_test_set3.json"
simulation4 = "results/singular_routes_sim/simulation_test_set4.json"
simulation5 = "results/singular_routes_sim/simulation_test_set5.json"
sims = [simulation1, simulation2, simulation3, simulation4, simulation5]

for sim in sims:
    with open(sim, "r") as file:
        simulation_results = json.load(file)

    degradation_data, losses_data = simulate_cycles(simulation_results, capacity, num_cycles=1500)
    plot_degradation_comparison(degradation_data)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import json
import os

def get_routes_sequence(sim_results, route_type="distance"):
    """
    Extract and randomly shuffle routes of a specific type from sim_results.
    
    Parameters:
    sim_results (dict): Dictionary containing all simulation results
    route_type (str): Type of routes to extract (e.g., 'distance', 'optimised')
    
    Returns:
    list: Shuffled list of route tuples (key, test, test_data)
    """
    all_routes = []
    
    for key, values in sim_results.items():
        for test, test_data in values.items():
            if route_type in test:
                for id, item in test_data.items():
                    all_routes.append((key, test, test_data))
                    break
    
    # Shuffle the routes randomly
    random.shuffle(all_routes)
    return all_routes

def simulate_discharge_for_route_type(sim_results, initial_capacity, route_type="distance", seed=None):
    """
    Simulate battery discharge for a specific route type.
    
    Parameters:
    sim_results (dict): Dictionary containing all simulation results
    initial_capacity (float): Initial battery capacity
    route_type (str): Type of routes to use (e.g., 'distance', 'optimised')
    seed (int): Random seed for route shuffling (None for random, value for deterministic)
    
    Returns:
    tuple: (results_dict, final_capacity, cap_loss_list, battery_capacity_list, distance_travelled_list)
    """
    results_dict = {}
    cap_loss_list = []
    battery_capacity = []
    distance_travelled = []
    
    # Set random seed if provided
    if seed is not None:
        random.seed(seed)
    
    # Get routes for this simulation
    all_routes = get_routes_sequence(sim_results, route_type)
    
    # Initialize with starting capacity
    current_capacity = initial_capacity
    
    # Process routes one by one until capacity drops below threshold
    route_index = 0
    while current_capacity >= initial_capacity * 0.6 and route_index < len(all_routes):
        key, test, test_data = all_routes[route_index]
        
        # Initialize dictionary entries if needed
        if key not in results_dict:
            results_dict[key] = {}
        results_dict[key][test] = {}
        
        # Calculate capacity loss using the current capacity value
        capacity_loss = 2 * bd.route_analysis(
            test_data['detailed_results'], 
            test_data['current_list'], 
            test_data['consumptions'],
            OCV, 
            current_capacity,
            base_k = 0.047,
            c_rate_exp = 1.2
        )
        
        # Store results
        cap_loss_list.append(capacity_loss)
        results_dict[key][test]['capacity_loss'] = capacity_loss
        results_dict[key][test]['consumption'] = test_data['total_consumption']
        distance_travelled.append(test_data['total_distance'])
        
        # Update capacity for the next route
        current_capacity = find_next_capacity(current_capacity, test_data['total_consumption'])
        battery_capacity.append(current_capacity)
        
        # Move to next route
        route_index += 1
    
    return results_dict, current_capacity, cap_loss_list, battery_capacity, distance_travelled

def compare_discharge_simulations(sim_results, regular_capacity, optimised_capacity, seed=None):
    """
    Compare battery discharge for both regular and optimized routes using the same random sequence.
    
    Parameters:
    sim_results (dict): Dictionary containing all simulation results
    regular_capacity (float): Current capacity for regular routes simulation
    optimised_capacity (float): Current capacity for optimised routes simulation
    seed (int): Random seed for reproducibility (None for random selection)
    
    Returns:
    dict: Combined results from both simulations
    """
    # Use a fixed seed for reproducibility and to ensure both simulations use the same random sequence
    if seed is None:
        random_seed = random.randint(0, 9999)
    else:
        random_seed = seed
    
    # Run simulation for regular distance routes
    results_dict_regular, final_capacity_regular, cap_loss_regular, \
    battery_capacity_regular, distance_travelled_regular = simulate_discharge_for_route_type(
        sim_results, regular_capacity, route_type="distance", seed=random_seed
    )
    
    # Run simulation for optimised routes with the same seed
    results_dict_optimised, final_capacity_optimised, cap_loss_optimised, \
    battery_capacity_optimised, distance_travelled_optimised = simulate_discharge_for_route_type(
        sim_results, optimised_capacity, route_type="optimised", seed=random_seed
    )
    
    # Combine results for comparison
    comparison_results = {
        'random_seed': random_seed,
        'regular': {
            'results_dict': results_dict_regular,
            'final_capacity': final_capacity_regular,
            'cap_loss_list': cap_loss_regular,
            'battery_capacity': battery_capacity_regular,
            'distance_travelled': distance_travelled_regular,
        },
        'optimised': {
            'results_dict': results_dict_optimised,
            'final_capacity': final_capacity_optimised,
            'cap_loss_list': cap_loss_optimised,
            'battery_capacity': battery_capacity_optimised,
            'distance_travelled': distance_travelled_optimised,
        }
    }
    
    return comparison_results

# Simulate multiple battery discharge cycles and track degradation
def simulate_cycles(sim_results, initial_capacity, num_cycles=600, seed=None):
    """
    Simulate multiple battery discharge cycles, tracking degradation over time.
    
    Parameters:
    sim_results (dict): Dictionary containing all simulation results
    initial_capacity (float): Initial battery capacity
    num_cycles (int): Number of cycles to simulate
    seed (int): Random seed for reproducibility (None for random selection)
    
    Returns:
    tuple: (degradation_data, losses_data)
        - degradation_data: Dictionary with capacity over time for regular and optimized routes
        - losses_data: Dictionary with capacity losses for each cycle
    """
    # Initialize tracking variables
    regular_capacity = initial_capacity
    optimised_capacity = initial_capacity
    
    regular_degradation = [regular_capacity]
    optimised_degradation = [optimised_capacity]
    
    regular_losses = []
    optimised_losses = []
    
    cycle_numbers = [0]
    
    # Track termination status for each battery type
    regular_terminated = False
    optimised_terminated = False
    
    for cycle in range(1, num_cycles + 1):
        # Run simulations for this cycle
        # If a battery has reached termination threshold, we still simulate but won't update its capacity further
        comparison_results = compare_discharge_simulations(
            sim_results, 
            regular_capacity if not regular_terminated else initial_capacity * 0.2,
            optimised_capacity if not optimised_terminated else initial_capacity * 0.2,
            seed=seed  # Pass the seed parameter
        )
        
        # Accumulate losses from this cycle
        regular_cycle_loss = sum(comparison_results['regular']['cap_loss_list']) if not regular_terminated else 0
        optimised_cycle_loss = sum(comparison_results['optimised']['cap_loss_list']) if not optimised_terminated else 0
        
        # Update capacities only if not terminated
        if not regular_terminated:
            regular_capacity -= regular_cycle_loss
            # Check if regular has now reached termination
            if regular_capacity < 0.2 * initial_capacity:
                regular_capacity = 0.2 * initial_capacity  # Floor at 20%
                regular_terminated = True
                print(f"Regular routes battery terminated at cycle {cycle}")
        
        if not optimised_terminated:
            optimised_capacity -= optimised_cycle_loss
            # Check if optimised has now reached termination
            if optimised_capacity < 0.2 * initial_capacity:
                optimised_capacity = 0.2 * initial_capacity  # Floor at 20%
                optimised_terminated = True
                print(f"Optimised routes battery terminated at cycle {cycle}")
        
        # Store data for this cycle
        regular_degradation.append(regular_capacity)
        optimised_degradation.append(optimised_capacity)
        regular_losses.append(regular_cycle_loss)
        optimised_losses.append(optimised_cycle_loss)
        cycle_numbers.append(cycle)
        
        # Terminate simulation only when both batteries have reached end of life
        if regular_terminated and optimised_terminated:
            print(f"Both batteries terminated. Ending simulation at cycle {cycle}")
            break
    
    # Compile results
    degradation_data = {
        'cycles': cycle_numbers,
        'regular_capacity': regular_degradation,
        'optimised_capacity': optimised_degradation,
        'capacity_percentage_regular': [cap/initial_capacity*100 for cap in regular_degradation],
        'capacity_percentage_optimised': [cap/initial_capacity*100 for cap in optimised_degradation],
        'random_seed': seed
    }
    
    losses_data = {
        'cycles': cycle_numbers[1:],
        'regular_losses': regular_losses,
        'optimised_losses': optimised_losses,
        'random_seed': seed
    }
    
    return degradation_data, losses_data

def plot_degradation_comparison(degradation_data, seed=None):
    """
    Plot the battery degradation comparison between regular and optimized routes.
    
    Parameters:
    degradation_data (dict): Dictionary containing degradation data from simulate_cycles
    seed (int): Random seed used for this simulation (for labeling)
    """
    plt.figure(figsize=(10, 6))
    plt.plot(degradation_data['cycles'], degradation_data['capacity_percentage_regular'], 'b-', label='Regular Routes')
    plt.plot(degradation_data['cycles'], degradation_data['capacity_percentage_optimised'], 'g-', label='Optimised Routes')
    plt.xlabel('Cycle Number')
    plt.ylabel('Remaining Capacity (%)')
    
    seed_info = f"Seed: {seed}" if seed is not None else ""
    plt.title(f'Battery Degradation Comparison {seed_info}')
    
    plt.legend()
    plt.grid(True)
    plt.axhline(y=60, color='r', linestyle='--', label='End of Life (60%)')
    plt.show()

def run_multiple_random_simulations(simulation_file, capacity, num_cycles=1500, num_random_sets=5, show_individual_plots=False):
    """
    Run multiple random simulations for a given simulation file.
    
    Parameters:
    simulation_file (str): Path to the simulation JSON file
    capacity (float): Initial battery capacity
    num_cycles (int): Number of cycles to simulate
    num_random_sets (int): Number of random sets to generate
    show_individual_plots (bool): Whether to show individual plots for each random set
    """
    # Load simulation data
    with open(simulation_file, "r") as file:
        simulation_results = json.load(file)
    
    sim_name = os.path.basename(simulation_file).replace(".json", "")
    
    all_degradation_data = []
    all_losses_data = []
    
    # Run multiple random simulations
    for i in range(num_random_sets):
        # Generate a unique seed for this simulation
        seed = random.randint(0, 99999)
        print(f"Running simulation {sim_name}, random set {i+1}/{num_random_sets} with seed {seed}")
        
        # Run the simulation with this seed
        degradation_data, losses_data = simulate_cycles(
            simulation_results, 
            capacity, 
            num_cycles=num_cycles,
            seed=seed
        )
        
        # Add to collection of all results
        all_degradation_data.append(degradation_data)
        all_losses_data.append(losses_data)
        
        # Plot individual result if requested
        if show_individual_plots:
            plot_degradation_comparison(
                degradation_data,
                seed=seed
            )
    
    return all_degradation_data, all_losses_data

def plot_combined_degradation(all_degradation_data, sim_name):
    """
    Plot all degradation curves on a single plot for comparison.
    
    Parameters:
    all_degradation_data (list): List of degradation data dictionaries
    sim_name (str): Name of the simulation for the plot title
    """
    plt.figure(figsize=(12, 8))
    
    # Plot each set with slightly transparent lines
    for i, degradation_data in enumerate(all_degradation_data):
        seed = degradation_data.get('random_seed', f"Set {i+1}")
        
        # Regular routes in blue shades
        plt.plot(
            degradation_data['cycles'], 
            degradation_data['capacity_percentage_regular'], 
            'b-', 
            alpha=0.3, 
            label=f"Regular (Seed {seed})" if i == 0 else ""
        )
        
        # Optimized routes in green shades
        plt.plot(
            degradation_data['cycles'], 
            degradation_data['capacity_percentage_optimised'], 
            'g-', 
            alpha=0.3, 
            label=f"Optimised (Seed {seed})" if i == 0 else ""
        )
    
    # If we have multiple data sets, calculate and plot averages
    if len(all_degradation_data) > 1:
        # Calculate average degradation curves
        max_cycles = max([max(data['cycles']) for data in all_degradation_data])
        avg_cycles = list(range(0, int(max_cycles) + 1))
        
        # Initialize arrays for summing up values
        sum_regular = np.zeros(len(avg_cycles))
        sum_optimised = np.zeros(len(avg_cycles))
        count_regular = np.zeros(len(avg_cycles))
        count_optimised = np.zeros(len(avg_cycles))
        
        # Sum up all values for each cycle
        for data in all_degradation_data:
            for i, cycle in enumerate(data['cycles']):
                if cycle < len(avg_cycles):
                    sum_regular[cycle] += data['capacity_percentage_regular'][i]
                    sum_optimised[cycle] += data['capacity_percentage_optimised'][i]
                    count_regular[cycle] += 1
                    count_optimised[cycle] += 1
        
        # Calculate averages (avoiding division by zero)
        avg_regular = np.divide(sum_regular, count_regular, out=np.zeros_like(sum_regular), where=count_regular!=0)
        avg_optimised = np.divide(sum_optimised, count_optimised, out=np.zeros_like(sum_optimised), where=count_optimised!=0)
        
        # Plot averages with thicker lines
        plt.plot(avg_cycles, avg_regular, 'b-', linewidth=2, label='Average Regular')
        plt.plot(avg_cycles, avg_optimised, 'g-', linewidth=2, label='Average Optimised')
    
    plt.xlabel('Cycle Number')
    plt.ylabel('Remaining Capacity (%)')
    plt.title(f'Battery Degradation Comparison - {sim_name} (All Random Sets)')
    plt.legend()
    plt.grid(True)
    plt.axhline(y=60, color='r', linestyle='--', label='End of Life (60%)')
    plt.show()

# Example usage
def main():
    # Just use the first simulation file
    simulation_file = "results/singular_routes_sim/simulation_test_set1.json"
    
    sim_name = os.path.basename(simulation_file).replace(".json", "")
    print(f"\nProcessing simulation file: {simulation_file}")
    
    # Run 100 random simulations without showing individual plots (would be too many)
    all_degradation, all_losses = run_multiple_random_simulations(
        simulation_file,
        capacity,
        num_cycles=1500,
        num_random_sets=100,
        show_individual_plots=False
    )

    print(f"Completed processing for {sim_name} with 100 random route sets")

    return all_degradation, sim_name

# %%
all_degradation, sim_name = main()
# Out:
# Processing simulation file: results/singular_routes_sim/simulation_test_set1.json
# Running simulation simulation_test_set1, random set 1/100 with seed 86987
# Regular routes battery terminated at cycle 721
# Optimised routes battery terminated at cycle 848
# Both batteries terminated. Ending simulation at cycle 848
# Running simulation simulation_test_set1, random set 2/100 with seed 76472
# Regular routes battery terminated at cycle 646
# Optimised routes battery terminated at cycle 702
# Both batteries terminated. Ending simulation at cycle 702
# Running simulation simulation_test_set1, random set 3/100 with seed 47904
# Regular routes battery terminated at cycle 755
# Optimised routes battery terminated at cycle 842
# Both batteries terminated. Ending simulation at cycle 842
# Running simulation simulation_test_set1, random set 4/100 with seed 88136
# Regular routes battery terminated at cycle 637
# Optimised routes battery terminated at cycle 893
# Both batteries terminated. Ending simulation at cycle 893
# Running simulation simulation_test_set1, random set 5/100 with seed 45098
# Regular routes battery terminated at cycle 901
# Optimised routes battery terminated at cycle 978
# Both batteries terminated. Ending simulation at cycle 978
# Running simulation simulation_test_set1, random set 6/100 with seed 36572
# Regular routes battery terminated at cycle 712
# Optimised routes battery terminated at cycle 865
# Both batteries terminated. Ending simulation at cycle 865
# Running simulation simulation_test_set1, random set 7/100 with seed 8611
# Regular routes battery terminated at cycle 854
# Optimised routes battery terminated at cycle 1045
# Both batteries terminated. Ending simulation at cycle 1045
# Running simulation simulation_test_set1, random set 8/100 with seed 83728
# Regular routes battery terminated at cycle 733
# Optimised routes battery terminated at cycle 863
# Both batteries terminated. Ending simulation at cycle 863
# Running simulation simulation_test_set1, random set 9/100 with seed 50795
# Regular routes battery terminated at cycle 731
# Optimised routes battery terminated at cycle 901
# Both batteries terminated. Ending simulation at cycle 901
# Running simulation simulation_test_set1, random set 10/100 with seed 14590
# Regular routes battery terminated at cycle 783
# Optimised routes battery terminated at cycle 867
# Both batteries terminated. Ending simulation at cycle 867
# Running simulation simulation_test_set1, random set 11/100 with seed 90999
# Regular routes battery terminated at cycle 745
# Optimised routes battery terminated at cycle 817
# Both batteries terminated. Ending simulation at cycle 817
# Running simulation simulation_test_set1, random set 12/100 with seed 65704
# Regular routes battery terminated at cycle 702
# Optimised routes battery terminated at cycle 727
# Both batteries terminated. Ending simulation at cycle 727
# Running simulation simulation_test_set1, random set 13/100 with seed 76094
# Regular routes battery terminated at cycle 697
# Optimised routes battery terminated at cycle 737
# Both batteries terminated. Ending simulation at cycle 737
# Running simulation simulation_test_set1, random set 14/100 with seed 28538
# Regular routes battery terminated at cycle 794
# Optimised routes battery terminated at cycle 901
# Both batteries terminated. Ending simulation at cycle 901
# Running simulation simulation_test_set1, random set 15/100 with seed 44403
# Regular routes battery terminated at cycle 702
# Optimised routes battery terminated at cycle 940
# Both batteries terminated. Ending simulation at cycle 940
# Running simulation simulation_test_set1, random set 16/100 with seed 44321
# Regular routes battery terminated at cycle 647
# Optimised routes battery terminated at cycle 746
# Both batteries terminated. Ending simulation at cycle 746
# Running simulation simulation_test_set1, random set 17/100 with seed 8655
# Regular routes battery terminated at cycle 684
# Optimised routes battery terminated at cycle 785
# Both batteries terminated. Ending simulation at cycle 785
# Running simulation simulation_test_set1, random set 18/100 with seed 99357
# Regular routes battery terminated at cycle 762
# Optimised routes battery terminated at cycle 786
# Both batteries terminated. Ending simulation at cycle 786
# Running simulation simulation_test_set1, random set 19/100 with seed 20194
# Regular routes battery terminated at cycle 740
# Optimised routes battery terminated at cycle 796
# Both batteries terminated. Ending simulation at cycle 796
# Running simulation simulation_test_set1, random set 20/100 with seed 74466
# Regular routes battery terminated at cycle 639
# Optimised routes battery terminated at cycle 712
# Both batteries terminated. Ending simulation at cycle 712
# Running simulation simulation_test_set1, random set 21/100 with seed 69279
# Regular routes battery terminated at cycle 787
# Optimised routes battery terminated at cycle 964
# Both batteries terminated. Ending simulation at cycle 964
# Running simulation simulation_test_set1, random set 22/100 with seed 91328
# Regular routes battery terminated at cycle 976
# Optimised routes battery terminated at cycle 1122
# Both batteries terminated. Ending simulation at cycle 1122
# Running simulation simulation_test_set1, random set 23/100 with seed 99925
# Regular routes battery terminated at cycle 677
# Optimised routes battery terminated at cycle 761
# Both batteries terminated. Ending simulation at cycle 761
# Running simulation simulation_test_set1, random set 24/100 with seed 75402
# Regular routes battery terminated at cycle 689
# Optimised routes battery terminated at cycle 767
# Both batteries terminated. Ending simulation at cycle 767
# Running simulation simulation_test_set1, random set 25/100 with seed 72072
# Regular routes battery terminated at cycle 865
# Optimised routes battery terminated at cycle 943
# Both batteries terminated. Ending simulation at cycle 943
# Running simulation simulation_test_set1, random set 26/100 with seed 2027
# Optimised routes battery terminated at cycle 694
# Regular routes battery terminated at cycle 783
# Both batteries terminated. Ending simulation at cycle 783
# Running simulation simulation_test_set1, random set 27/100 with seed 52535
# Optimised routes battery terminated at cycle 688
# Regular routes battery terminated at cycle 699
# Both batteries terminated. Ending simulation at cycle 699
# Running simulation simulation_test_set1, random set 28/100 with seed 71192
# Regular routes battery terminated at cycle 748
# Optimised routes battery terminated at cycle 828
# Both batteries terminated. Ending simulation at cycle 828
# Running simulation simulation_test_set1, random set 29/100 with seed 38187
# Regular routes battery terminated at cycle 730
# Optimised routes battery terminated at cycle 780
# Both batteries terminated. Ending simulation at cycle 780
# Running simulation simulation_test_set1, random set 30/100 with seed 53087
# Regular routes battery terminated at cycle 743
# Optimised routes battery terminated at cycle 852
# Both batteries terminated. Ending simulation at cycle 852
# Running simulation simulation_test_set1, random set 31/100 with seed 93901
# Regular routes battery terminated at cycle 810
# Optimised routes battery terminated at cycle 905
# Both batteries terminated. Ending simulation at cycle 905
# Running simulation simulation_test_set1, random set 32/100 with seed 19636
# Regular routes battery terminated at cycle 772
# Optimised routes battery terminated at cycle 838
# Both batteries terminated. Ending simulation at cycle 838
# Running simulation simulation_test_set1, random set 33/100 with seed 53844
# Regular routes battery terminated at cycle 706
# Optimised routes battery terminated at cycle 834
# Both batteries terminated. Ending simulation at cycle 834
# Running simulation simulation_test_set1, random set 34/100 with seed 73924
# Regular routes battery terminated at cycle 665
# Optimised routes battery terminated at cycle 701
# Both batteries terminated. Ending simulation at cycle 701
# Running simulation simulation_test_set1, random set 35/100 with seed 47962
# Regular routes battery terminated at cycle 639
# Optimised routes battery terminated at cycle 750
# Both batteries terminated. Ending simulation at cycle 750
# Running simulation simulation_test_set1, random set 36/100 with seed 1649
# Regular routes battery terminated at cycle 673
# Optimised routes battery terminated at cycle 715
# Both batteries terminated. Ending simulation at cycle 715
# Running simulation simulation_test_set1, random set 37/100 with seed 55172
# Regular routes battery terminated at cycle 868
# Optimised routes battery terminated at cycle 907
# Both batteries terminated. Ending simulation at cycle 907
# Running simulation simulation_test_set1, random set 38/100 with seed 91602
# Regular routes battery terminated at cycle 706
# Optimised routes battery terminated at cycle 841
# Both batteries terminated. Ending simulation at cycle 841
# Running simulation simulation_test_set1, random set 39/100 with seed 51403
# Regular routes battery terminated at cycle 740
# Optimised routes battery terminated at cycle 777
# Both batteries terminated. Ending simulation at cycle 777
# Running simulation simulation_test_set1, random set 40/100 with seed 10742
# Regular routes battery terminated at cycle 745
# Optimised routes battery terminated at cycle 925
# Both batteries terminated. Ending simulation at cycle 925
# Running simulation simulation_test_set1, random set 41/100 with seed 99801
# Optimised routes battery terminated at cycle 778
# Regular routes battery terminated at cycle 791
# Both batteries terminated. Ending simulation at cycle 791
# Running simulation simulation_test_set1, random set 42/100 with seed 27075
# Regular routes battery terminated at cycle 833
# Optimised routes battery terminated at cycle 990
# Both batteries terminated. Ending simulation at cycle 990
# Running simulation simulation_test_set1, random set 43/100 with seed 9354
# Regular routes battery terminated at cycle 723
# Optimised routes battery terminated at cycle 816
# Both batteries terminated. Ending simulation at cycle 816
# Running simulation simulation_test_set1, random set 44/100 with seed 15572
# Regular routes battery terminated at cycle 781
# Optimised routes battery terminated at cycle 850
# Both batteries terminated. Ending simulation at cycle 850
# Running simulation simulation_test_set1, random set 45/100 with seed 65634
# Regular routes battery terminated at cycle 769
# Optimised routes battery terminated at cycle 849
# Both batteries terminated. Ending simulation at cycle 849
# Running simulation simulation_test_set1, random set 46/100 with seed 63086
# Optimised routes battery terminated at cycle 837
# Regular routes battery terminated at cycle 840
# Both batteries terminated. Ending simulation at cycle 840
# Running simulation simulation_test_set1, random set 47/100 with seed 85034
# Optimised routes battery terminated at cycle 828
# Regular routes battery terminated at cycle 841
# Both batteries terminated. Ending simulation at cycle 841
# Running simulation simulation_test_set1, random set 48/100 with seed 71821
# Regular routes battery terminated at cycle 741
# Optimised routes battery terminated at cycle 786
# Both batteries terminated. Ending simulation at cycle 786
# Running simulation simulation_test_set1, random set 49/100 with seed 68034
# Regular routes battery terminated at cycle 735
# Optimised routes battery terminated at cycle 796
# Both batteries terminated. Ending simulation at cycle 796
# Running simulation simulation_test_set1, random set 50/100 with seed 36247
# Regular routes battery terminated at cycle 765
# Optimised routes battery terminated at cycle 852
# Both batteries terminated. Ending simulation at cycle 852
# Running simulation simulation_test_set1, random set 51/100 with seed 61854
# Optimised routes battery terminated at cycle 680
# Regular routes battery terminated at cycle 710
# Both batteries terminated. Ending simulation at cycle 710
# Running simulation simulation_test_set1, random set 52/100 with seed 73247
# Regular routes battery terminated at cycle 765
# Optimised routes battery terminated at cycle 824
# Both batteries terminated. Ending simulation at cycle 824
# Running simulation simulation_test_set1, random set 53/100 with seed 44458
# Regular routes battery terminated at cycle 724
# Optimised routes battery terminated at cycle 888
# Both batteries terminated. Ending simulation at cycle 888
# Running simulation simulation_test_set1, random set 54/100 with seed 44387
# Regular routes battery terminated at cycle 641
# Optimised routes battery terminated at cycle 764
# Both batteries terminated. Ending simulation at cycle 764
# Running simulation simulation_test_set1, random set 55/100 with seed 72191
# Optimised routes battery terminated at cycle 837
# Regular routes battery terminated at cycle 844
# Both batteries terminated. Ending simulation at cycle 844
# Running simulation simulation_test_set1, random set 56/100 with seed 51375
# Regular routes battery terminated at cycle 719
# Optimised routes battery terminated at cycle 840
# Both batteries terminated. Ending simulation at cycle 840
# Running simulation simulation_test_set1, random set 57/100 with seed 62701
# Regular routes battery terminated at cycle 585
# Optimised routes battery terminated at cycle 743
# Both batteries terminated. Ending simulation at cycle 743
# Running simulation simulation_test_set1, random set 58/100 with seed 13674
# Optimised routes battery terminated at cycle 810
# Regular routes battery terminated at cycle 848
# Both batteries terminated. Ending simulation at cycle 848
# Running simulation simulation_test_set1, random set 59/100 with seed 98152
# Regular routes battery terminated at cycle 705
# Optimised routes battery terminated at cycle 858
# Both batteries terminated. Ending simulation at cycle 858
# Running simulation simulation_test_set1, random set 60/100 with seed 38260
# Regular routes battery terminated at cycle 654
# Optimised routes battery terminated at cycle 721
# Both batteries terminated. Ending simulation at cycle 721
# Running simulation simulation_test_set1, random set 61/100 with seed 92911
# Regular routes battery terminated at cycle 869
# Optimised routes battery terminated at cycle 870
# Both batteries terminated. Ending simulation at cycle 870
# Running simulation simulation_test_set1, random set 62/100 with seed 19310
# Regular routes battery terminated at cycle 703
# Optimised routes battery terminated at cycle 833
# Both batteries terminated. Ending simulation at cycle 833
# Running simulation simulation_test_set1, random set 63/100 with seed 27199
# Regular routes battery terminated at cycle 766
# Optimised routes battery terminated at cycle 954
# Both batteries terminated. Ending simulation at cycle 954
# Running simulation simulation_test_set1, random set 64/100 with seed 96172
# Regular routes battery terminated at cycle 759
# Optimised routes battery terminated at cycle 759
# Both batteries terminated. Ending simulation at cycle 759
# Running simulation simulation_test_set1, random set 65/100 with seed 24487
# Regular routes battery terminated at cycle 828
# Optimised routes battery terminated at cycle 891
# Both batteries terminated. Ending simulation at cycle 891
# Running simulation simulation_test_set1, random set 66/100 with seed 54602
# Regular routes battery terminated at cycle 641
# Optimised routes battery terminated at cycle 664
# Both batteries terminated. Ending simulation at cycle 664
# Running simulation simulation_test_set1, random set 67/100 with seed 9546
# Regular routes battery terminated at cycle 689
# Optimised routes battery terminated at cycle 746
# Both batteries terminated. Ending simulation at cycle 746
# Running simulation simulation_test_set1, random set 68/100 with seed 65990
# Regular routes battery terminated at cycle 739
# Optimised routes battery terminated at cycle 851
# Both batteries terminated. Ending simulation at cycle 851
# Running simulation simulation_test_set1, random set 69/100 with seed 67314
# Regular routes battery terminated at cycle 729
# Optimised routes battery terminated at cycle 836
# Both batteries terminated. Ending simulation at cycle 836
# Running simulation simulation_test_set1, random set 70/100 with seed 24243
# Regular routes battery terminated at cycle 747
# Optimised routes battery terminated at cycle 863
# Both batteries terminated. Ending simulation at cycle 863
# Running simulation simulation_test_set1, random set 71/100 with seed 60778
# Regular routes battery terminated at cycle 761
# Optimised routes battery terminated at cycle 940
# Both batteries terminated. Ending simulation at cycle 940
# Running simulation simulation_test_set1, random set 72/100 with seed 76256
# Regular routes battery terminated at cycle 862
# Optimised routes battery terminated at cycle 885
# Both batteries terminated. Ending simulation at cycle 885
# Running simulation simulation_test_set1, random set 73/100 with seed 9736
# Regular routes battery terminated at cycle 710
# Optimised routes battery terminated at cycle 797
# Both batteries terminated. Ending simulation at cycle 797
# Running simulation simulation_test_set1, random set 74/100 with seed 23152
# Regular routes battery terminated at cycle 770
# Optimised routes battery terminated at cycle 901
# Both batteries terminated. Ending simulation at cycle 901
# Running simulation simulation_test_set1, random set 75/100 with seed 5459
# Regular routes battery terminated at cycle 770
# Optimised routes battery terminated at cycle 823
# Both batteries terminated. Ending simulation at cycle 823
# Running simulation simulation_test_set1, random set 76/100 with seed 70283
# Optimised routes battery terminated at cycle 838
# Regular routes battery terminated at cycle 931
# Both batteries terminated. Ending simulation at cycle 931
# Running simulation simulation_test_set1, random set 77/100 with seed 81665
# Optimised routes battery terminated at cycle 737
# Regular routes battery terminated at cycle 795
# Both batteries terminated. Ending simulation at cycle 795
# Running simulation simulation_test_set1, random set 78/100 with seed 17135
# Regular routes battery terminated at cycle 794
# Optimised routes battery terminated at cycle 835
# Both batteries terminated. Ending simulation at cycle 835
# Running simulation simulation_test_set1, random set 79/100 with seed 23962
# Regular routes battery terminated at cycle 714
# Optimised routes battery terminated at cycle 762
# Both batteries terminated. Ending simulation at cycle 762
# Running simulation simulation_test_set1, random set 80/100 with seed 95834
# Regular routes battery terminated at cycle 723
# Optimised routes battery terminated at cycle 767
# Both batteries terminated. Ending simulation at cycle 767
# Running simulation simulation_test_set1, random set 81/100 with seed 62907
# Regular routes battery terminated at cycle 736
# Optimised routes battery terminated at cycle 957
# Both batteries terminated. Ending simulation at cycle 957
# Running simulation simulation_test_set1, random set 82/100 with seed 88545
# Regular routes battery terminated at cycle 753
# Optimised routes battery terminated at cycle 826
# Both batteries terminated. Ending simulation at cycle 826
# Running simulation simulation_test_set1, random set 83/100 with seed 70588
# Regular routes battery terminated at cycle 766
# Optimised routes battery terminated at cycle 824
# Both batteries terminated. Ending simulation at cycle 824
# Running simulation simulation_test_set1, random set 84/100 with seed 27298
# Regular routes battery terminated at cycle 768
# Optimised routes battery terminated at cycle 903
# Both batteries terminated. Ending simulation at cycle 903
# Running simulation simulation_test_set1, random set 85/100 with seed 73505
# Regular routes battery terminated at cycle 716
# Optimised routes battery terminated at cycle 817
# Both batteries terminated. Ending simulation at cycle 817
# Running simulation simulation_test_set1, random set 86/100 with seed 76444
# Regular routes battery terminated at cycle 756
# Optimised routes battery terminated at cycle 821
# Both batteries terminated. Ending simulation at cycle 821
# Running simulation simulation_test_set1, random set 87/100 with seed 14002
# Regular routes battery terminated at cycle 726
# Optimised routes battery terminated at cycle 800
# Both batteries terminated. Ending simulation at cycle 800
# Running simulation simulation_test_set1, random set 88/100 with seed 43000
# Regular routes battery terminated at cycle 774
# Optimised routes battery terminated at cycle 844
# Both batteries terminated. Ending simulation at cycle 844
# Running simulation simulation_test_set1, random set 89/100 with seed 33299
# Regular routes battery terminated at cycle 748
# Optimised routes battery terminated at cycle 838
# Both batteries terminated. Ending simulation at cycle 838
# Running simulation simulation_test_set1, random set 90/100 with seed 62715
# Regular routes battery terminated at cycle 750
# Optimised routes battery terminated at cycle 827
# Both batteries terminated. Ending simulation at cycle 827
# Running simulation simulation_test_set1, random set 91/100 with seed 81394
# Regular routes battery terminated at cycle 684
# Optimised routes battery terminated at cycle 715
# Both batteries terminated. Ending simulation at cycle 715
# Running simulation simulation_test_set1, random set 92/100 with seed 34432
# Regular routes battery terminated at cycle 803
# Optimised routes battery terminated at cycle 813
# Both batteries terminated. Ending simulation at cycle 813
# Running simulation simulation_test_set1, random set 93/100 with seed 19996
# Regular routes battery terminated at cycle 809
# Optimised routes battery terminated at cycle 987
# Both batteries terminated. Ending simulation at cycle 987
# Running simulation simulation_test_set1, random set 94/100 with seed 91607
# Regular routes battery terminated at cycle 666
# Optimised routes battery terminated at cycle 752
# Both batteries terminated. Ending simulation at cycle 752
# Running simulation simulation_test_set1, random set 95/100 with seed 351
# Regular routes battery terminated at cycle 659
# Optimised routes battery terminated at cycle 786
# Both batteries terminated. Ending simulation at cycle 786
# Running simulation simulation_test_set1, random set 96/100 with seed 83516
# Regular routes battery terminated at cycle 710
# Optimised routes battery terminated at cycle 803
# Both batteries terminated. Ending simulation at cycle 803
# Running simulation simulation_test_set1, random set 97/100 with seed 67789
# Regular routes battery terminated at cycle 642
# Optimised routes battery terminated at cycle 747
# Both batteries terminated. Ending simulation at cycle 747
# Running simulation simulation_test_set1, random set 98/100 with seed 13679
# Regular routes battery terminated at cycle 641
# Optimised routes battery terminated at cycle 657
# Both batteries terminated. Ending simulation at cycle 657
# Running simulation simulation_test_set1, random set 99/100 with seed 48327
# Regular routes battery terminated at cycle 680
# Optimised routes battery terminated at cycle 757
# Both batteries terminated. Ending simulation at cycle 757
# Running simulation simulation_test_set1, random set 100/100 with seed 75482
# Regular routes battery terminated at cycle 768
# Optimised routes battery terminated at cycle 914
# Both batteries terminated. Ending simulation at cycle 914
# Completed processing for simulation_test_set1 with 100 random route sets

# %%
def plot_combined_degradation(all_degradation_data, sim_name):
    """
    Plot all degradation curves on a single plot for comparison.
    
    Parameters:
    all_degradation_data (list): List of degradation data dictionaries
    sim_name (str): Name of the simulation for the plot title
    """
    plt.figure(figsize=(12, 8))
    
            # Plot each set with slightly transparent lines
    for i, degradation_data in enumerate(all_degradation_data):
        seed = degradation_data.get('random_seed', f"Set {i+1}")
        
        # Regular routes in blue shades
        plt.plot(
            degradation_data['cycles'], 
            degradation_data['capacity_percentage_regular'], 
            'b-', 
            alpha=0.15, 
            label=f"Non-Optimised Algorithm" if i == 0 else ""
        )
        
        # Optimized routes in green shades
        plt.plot(
            degradation_data['cycles'], 
            degradation_data['capacity_percentage_optimised'], 
            'g-', 
            alpha=0.15, 
            label=f"Optimised Algorithm" if i == 0 else ""
        )
    
    # If we have multiple data sets, calculate and plot averages
    if len(all_degradation_data) > 1:
        # Calculate average degradation curves
        max_cycles = max([max(data['cycles']) for data in all_degradation_data])
        avg_cycles = list(range(0, int(max_cycles) + 1))
        
        # Initialize arrays for summing up values
        sum_regular = np.zeros(len(avg_cycles))
        sum_optimised = np.zeros(len(avg_cycles))
        count_regular = np.zeros(len(avg_cycles))
        count_optimised = np.zeros(len(avg_cycles))
        
        # Sum up all values for each cycle
        for data in all_degradation_data:
            for i, cycle in enumerate(data['cycles']):
                if cycle < len(avg_cycles):
                    sum_regular[cycle] += data['capacity_percentage_regular'][i]
                    sum_optimised[cycle] += data['capacity_percentage_optimised'][i]
                    count_regular[cycle] += 1
                    count_optimised[cycle] += 1
        
        # Calculate averages (avoiding division by zero)
        avg_regular = np.divide(sum_regular, count_regular, out=np.zeros_like(sum_regular), where=count_regular!=0)
        avg_optimised = np.divide(sum_optimised, count_optimised, out=np.zeros_like(sum_optimised), where=count_optimised!=0)
        
        # Plot averages with VERY visible lines
        # First plot wider black outline
        plt.plot(avg_cycles, avg_regular, color='black', linewidth=7, linestyle='-')
        plt.plot(avg_cycles, avg_optimised, color='black', linewidth=7, linestyle='-')
        
        # Then plot the colored lines on top - thicker and solid
        plt.plot(avg_cycles, avg_regular, color='blue', linewidth=5, linestyle='-', label='Average Regular')
        plt.plot(avg_cycles, avg_optimised, color='C2', linewidth=5, linestyle='-', label='Average Optimised')
        
        # Find where each average line crosses the 80% threshold
        regular_cross_point = None
        optimised_cross_point = None
        
        # Find first point where the value drops below 80%
        for i in range(len(avg_cycles)):
            # For regular algorithm
            if avg_regular[i] <= 80 and (i == 0 or avg_regular[i-1] > 80):
                # Linear interpolation for more accurate crossing point
                if i > 0:
                    y0, y1 = avg_regular[i-1], avg_regular[i]
                    x0, x1 = avg_cycles[i-1], avg_cycles[i]
                    regular_cross_point = x0 + (x1 - x0) * (80 - y0) / (y1 - y0)
                else:
                    regular_cross_point = avg_cycles[i]
            
            # For optimised algorithm
            if avg_optimised[i] <= 80 and (i == 0 or avg_optimised[i-1] > 80):
                # Linear interpolation for more accurate crossing point
                if i > 0:
                    y0, y1 = avg_optimised[i-1], avg_optimised[i]
                    x0, x1 = avg_cycles[i-1], avg_cycles[i]
                    optimised_cross_point = x0 + (x1 - x0) * (80 - y0) / (y1 - y0)
                else:
                    optimised_cross_point = avg_cycles[i]
        
        # Print where the lines cross 80%
        if regular_cross_point is not None:
            print(f"Non-Optimised Algorithm reaches 80% capacity at cycle {regular_cross_point:.2f}")
            # Add annotation to the plot with improved visibility and arrow
            plt.annotate(f"EOL at cycle {regular_cross_point:.1f}",
                         xy=(regular_cross_point, 80),
                         xytext=(regular_cross_point-70, 72),
                         arrowprops=dict(facecolor='blue', edgecolor='black', shrink=0.05, width=3),
                         fontsize=11,
                         bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.9, edgecolor='black'))
        else:
            print("Non-Optimised Algorithm does not reach 80% capacity in the given data")
        
        if optimised_cross_point is not None:
            print(f"Optimised Algorithm reaches 80% capacity at cycle {optimised_cross_point:.2f}")
            # Add annotation to the plot with improved visibility
            plt.annotate(f"EOL at cycle {optimised_cross_point:.1f}",
                         xy=(optimised_cross_point, 80),
                         xytext=(optimised_cross_point-70, 87),
                         arrowprops=dict(facecolor='green', edgecolor='black', shrink=0.05, width=3),
                         fontsize=11,
                         bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.9, edgecolor='black'))
        else:
            print("Optimised Algorithm does not reach 80% capacity in the given data")
    
    plt.xlabel('Cycle Number', fontsize=12)
    plt.ylabel('SOH(%)', fontsize=12)
    plt.ylim(60, 100)
    plt.xlim(0, 400)

    plt.title(f'End of Life Degradation Comparison', fontsize=14)
    plt.axhline(y=80, color='r', linestyle='--', linewidth=2, label='End of Life (80%)')
    plt.legend(fontsize=11, loc='upper right', framealpha=0.9)
    plt.grid(True, alpha=0.7)

    plt.show()


# Call the function
plot_combined_degradation(all_degradation, sim_name)
# Out:
# Non-Optimised Algorithm reaches 80% capacity at cycle 301.64
# Optimised Algorithm reaches 80% capacity at cycle 332.08
